# %% [markdown]
# # Capstone Database Engineer Course by Meta
# # Final Project Assessment
# ## Database Creation, Reading, Updating, and Deletion (CRUD) using .csv file, MySQL, MySQL WorkBench, Python, Jupyter Notebook, GitHub, and Visual Studio Code

# %% [markdown]
# # Initialization: Import required libraries.

# %%
#Import MySQL Connector/Python
import mysql.connector as connector
#Import the Error class from MySQL Connector/Python
from mysql.connector import Error
#Import Panda, required to create a dataframe with the data to record in the database
import pandas as pd

# %% [markdown]
# # Task 0: Connect to the Database designed and created using MySQL WorkBench.

# %%
#Define database configurations as a Python dictionary object called dbconfig
dbconfig={"host":"localhost","user":"root", "password":""}

# %%
#Connect to MySQL
def connectToMySQL():
    try:
        connection = connector.connect(**dbconfig)
        print("Successfully connected to MySQL.")
        return connection
    except Error as er:
        print("Something went wrong.")
        print("Error Code:", er.errno)
        print("Error Message:", er.msg)
        
cnx=connectToMySQL()
# Out:
# Successfully connected to MySQL.

# %%
#Create a cursor
cursor = cnx.cursor()
print("Cursor successfully created.")
# Out:
# Cursor successfully created.

# %%
#Set the database for use
try:
    use_database1_sql = """USE little_lemon_org_database""" 
    cursor.execute(use_database1_sql) 
    print("Database little_lemon_org_database is ready for use.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Database little_lemon_org_database is ready for use.

# %% [markdown]
# # Task 1: Tranform the data given and extract the data for each Table

# %%
#Create a dataframe with the .csv files provided
file_location_name = 'tables_data\LittleLemon_allData.csv'
df = pd.read_csv(file_location_name, index_col=False, delimiter = ',', keep_default_na=False, na_values=['']) 
df.head(5)
# Out:
#    Row Number     Order ID   Order Date Delivery Date  Customer ID  \
# 0           1  54-366-6861  15-Jun-2020   26-Mar-2020  72-055-7985
# 1           2  63-761-3686  25-Aug-2020   17-Jul-2020  65-353-0657
# 2           3  65-351-6434  17-Aug-2021   24-Apr-2020  90-876-6799
# 3           4  36-917-2834  14-Aug-2021   13-Apr-2020  73-873-4827
# 4           5  86-114-9232  20-Dec-2020    2-Feb-2021  80-927-5246
#
#      Customer Name        City      Country Postal Code Country Code  ...  \
# 0     Laney Fadden    Daruoyan        China    993-0031           CN  ...
# 1  Giacopo Bramich      Ongjin  North Korea      216282           KP  ...
# 2        Lia Bonar  Quince Mil         Peru      663246           PE  ...
# 3   Merrill Baudon      Susaki        Japan    987-0352           JP  ...
# 4     Tasia Fautly      Tobruk        Libya      351 01           LY  ...
#
#    Sales  Quantity  Discount  Delivery Cost  Course Name Cuisine Name  \
# 0  187.5         2     20.00          60.51  Greek salad        Greek
# 1  352.5         1     15.00          96.75    Bean soup      Italian
# 2  112.5         3     10.52          36.37        Pizza      Italian
# 3  330.0         3     11.23           5.49    Carbonara      Turkish
# 4  480.0         2     51.05          63.64       Kabasa        Greek
#
#    Starter Name      Desert Name              Drink         Sides
# 0        Olives    Greek yoghurt  Athens White wine         Tapas
# 1     Flatbread        Ice cream     Corfu Red Wine  Potato salad
# 2    Minestrone       Cheesecake     Italian Coffee    Bruschetta
# 3  Tomato bread         Affogato      Roma Red wine      Focaccia
# 4       Falafel  Turkish yoghurt  Ankara White Wine     Meatballs
#
# [5 rows x 21 columns]

# %%
# Get data types of columns before conversion
df.dtypes
# Out:
# Row Number         int64
# Order ID          object
# Order Date        object
# Delivery Date     object
# Customer ID       object
# Customer Name     object
# City              object
# Country           object
# Postal Code       object
# Country Code      object
# Cost             float64
# Sales            float64
# Quantity           int64
# Discount         float64
# Delivery Cost    float64
# Course Name       object
# Cuisine Name      object
# Starter Name      object
# Desert Name       object
# Drink             object
# Sides             object
# dtype: object

# %%
# Convert datatype of appropriate columns to date time
df["Order Date"]=df["Order Date"].apply(pd.to_datetime)
df["Delivery Date"]=df["Delivery Date"].apply(pd.to_datetime)
# Convert datatype of appropriate columns to string
df["Order ID"]=df["Order ID"].astype('string')
df["Customer ID"]=df["Customer ID"].astype('string')
df["Customer Name"]=df["Customer Name"].astype('string')
df["City"]=df["City"].astype('string')
df["Country"]=df["Country"].astype('string')
df["Postal Code"]=df["Postal Code"].astype('string')
df["Country Code"]=df["Country Code"].astype('string')
df["Course Name"]=df["Course Name"].astype('string')
df["Cuisine Name"]=df["Cuisine Name"].astype('string')
df["Starter Name"]=df["Starter Name"].astype('string')
df["Desert Name"]=df["Desert Name"].astype('string')
df["Drink"]=df["Drink"].astype('string')
df["Sides"]=df["Sides"].astype('string')
# Add 2 digits for the decimal part of floats
df["Cost"]=df["Cost"].round(decimals=2)
df["Sales"]=df["Sales"].round(2)
df["Discount"]=df["Discount"].round(2)
df["Delivery Cost"]=df["Delivery Cost"].round(2)

# %%
# Check for missing values
df.isna().sum()
# Out:
# Row Number       0
# Order ID         0
# Order Date       0
# Delivery Date    0
# Customer ID      0
# Customer Name    0
# City             0
# Country          0
# Postal Code      0
# Country Code     0
# Cost             0
# Sales            0
# Quantity         0
# Discount         0
# Delivery Cost    0
# Course Name      0
# Cuisine Name     0
# Starter Name     0
# Desert Name      0
# Drink            0
# Sides            0
# dtype: int64

# %%
# Generate the column AddressID with data from existing columns and a digit  
df["AddressID"]=df["City"].str.replace(' ', '', regex=False)+"-"+df["Country"].str[:3]+"-"+df["Postal Code"].str.replace('-', '', regex=False)+"-"+str(1)
df["AddressID"]=df["AddressID"].str.upper()

# Create the corresponding dataframe for Table DeliveryAddress
df_DeliveryAddress = df.filter(items=["AddressID", "City","Country","Postal Code","Country Code"])
# Rename columns as in DeliveryAddress Table
df_DeliveryAddress = df_DeliveryAddress.rename(columns={"Row Number":"AddressID","Postal Code":"PostalCode","Country Code":"CountryCode"})

# Delete dupplicate row because AddressID is a Primary key
df_DeliveryAddress = df_DeliveryAddress.drop_duplicates()

# Display first rows of DeliveryAddress Table
df_DeliveryAddress.head(5)
# Out:
#                 AddressID        City      Country PostalCode CountryCode
# 0  DARUOYAN-CHI-9930031-1    Daruoyan        China   993-0031          CN
# 1     ONGJIN-NOR-216282-1      Ongjin  North Korea     216282          KP
# 2  QUINCEMIL-PER-663246-1  Quince Mil         Peru     663246          PE
# 3    SUSAKI-JAP-9870352-1      Susaki        Japan   987-0352          JP
# 4     TOBRUK-LIB-351 01-1      Tobruk        Libya     351 01          LY

# %%
# Generate the column ProductID with data from existing columns and a digit  
df["ProductID"] = df["Course Name"].str[:3] + df["Cuisine Name"].str[:3] + df["Starter Name"].str[:3] + df["Desert Name"].str[:3] + df["Drink"].str[:3] + df["Sides"].str[:3] + str(1)

# Create the corresponding dataframe for Table Products
df_Produts = df.filter(items=["ProductID", "Course Name","Cuisine Name","Starter Name","Desert Name","Drink","Sides"])
# Rename columns as in Products Table
df_Produts = df_Produts.rename(columns={"Course Name":"CourseName","Cuisine Name":"CuisineName",
                                                        "Starter Name":"StarterName","Desert Name":"DesertName"})
# Delete dupplicate row because ProductID is a Primary key
df_Produts = df_Produts.drop_duplicates()

# Display first rows of Products Table
df_Produts.head(5)
# Out:
#              ProductID   CourseName CuisineName   StarterName  \
# 0  GreGreOliGreAthTap1  Greek salad       Greek        Olives
# 1  BeaItaFlaIceCorPot1    Bean soup     Italian     Flatbread
# 2  PizItaMinCheItaBru1        Pizza     Italian    Minestrone
# 3  CarTurTomAffRomFoc1    Carbonara     Turkish  Tomato bread
# 4  KabGreFalTurAnkMea1       Kabasa       Greek       Falafel
#
#         DesertName              Drink         Sides
# 0    Greek yoghurt  Athens White wine         Tapas
# 1        Ice cream     Corfu Red Wine  Potato salad
# 2       Cheesecake     Italian Coffee    Bruschetta
# 3         Affogato      Roma Red wine      Focaccia
# 4  Turkish yoghurt  Ankara White Wine     Meatballs

# %%
# Extract 2 new columns FirstName and LastName from the column Name
df["FirstName"]=df["Customer Name"].str.split(" ", n=1).str.get(0)
df["LastName"]=df["Customer Name"].str.split(" ", n=1).str.get(1)

# Create the corresponding dataframe for Table Customers
df_Customers = df.filter(items=["Customer ID", "FirstName","LastName"])
# Rename columns as in Customers Table
df_Customers = df_Customers.rename(columns={"Customer ID":"CustomerID"})

# Delete dupplicate row because CustomerID is a Primary key
df_Customers=df_Customers.drop_duplicates()

# Display first rows of Customers Table
df_Customers.head(5)
# Out:
#     CustomerID FirstName LastName
# 0  72-055-7985     Laney   Fadden
# 1  65-353-0657   Giacopo  Bramich
# 2  90-876-6799       Lia    Bonar
# 3  73-873-4827   Merrill   Baudon
# 4  80-927-5246     Tasia   Fautly

# %%
# Create the corresponding dataframe for Table Orders
df_Orders = df.filter(items=["Order ID", "Order Date","Customer ID"])
# Rename columns as in Customers Table
df_Orders = df_Orders.rename(columns={"Order ID":"OrderID","Order Date":"OrderDate","Customer ID":"CustomerID"})

# Delete dupplicate row because OrderID is a Primary key
df_Orders=df_Orders.drop_duplicates()

# Display first rows of Orders Table
df_Orders.head(5)
# Out:
#        OrderID  OrderDate   CustomerID
# 0  54-366-6861 2020-06-15  72-055-7985
# 1  63-761-3686 2020-08-25  65-353-0657
# 2  65-351-6434 2021-08-17  90-876-6799
# 3  36-917-2834 2021-08-14  73-873-4827
# 4  86-114-9232 2020-12-20  80-927-5246

# %%
# Create the corresponding dataframe for Table OrderDetails
df_OrderDetails = df.filter(items=["Delivery Date","Delivery Cost", "Quantity", "Cost", "Discount", "AddressID", "Order ID", "ProductID"])
# Rename columns as in DeliveryInfo Table
df_OrderDetails = df_OrderDetails.rename(columns={"Delivery Date":"DeliveryDate","Delivery Cost":"DeliveryCost","Cost":"CostPrice","Order ID":"OrderID"})

# Display first rows of OrderDetails Table
df_OrderDetails.head(5)
# Out:
#   DeliveryDate  DeliveryCost  Quantity  CostPrice  Discount  \
# 0   2020-03-26         60.51         2      125.0     20.00
# 1   2020-07-17         96.75         1      235.0     15.00
# 2   2020-04-24         36.37         3       75.0     10.52
# 3   2020-04-13          5.49         3      220.0     11.23
# 4   2021-02-02         63.64         2      320.0     51.05
#
#                 AddressID      OrderID            ProductID
# 0  DARUOYAN-CHI-9930031-1  54-366-6861  GreGreOliGreAthTap1
# 1     ONGJIN-NOR-216282-1  63-761-3686  BeaItaFlaIceCorPot1
# 2  QUINCEMIL-PER-663246-1  65-351-6434  PizItaMinCheItaBru1
# 3    SUSAKI-JAP-9870352-1  36-917-2834  CarTurTomAffRomFoc1
# 4     TOBRUK-LIB-351 01-1  86-114-9232  KabGreFalTurAnkMea1

# %% [markdown]
# # Task 2: Insert data into the Tables.

# %%
# %%time

#Insert records into the Table DeliveryAddress
try:
    insert_table_DeliveryAddress_sql = """INSERT INTO little_lemon_org_database.DeliveryAddress VALUES (%s,%s,%s,%s,%s)""" 
    for i,row in df_DeliveryAddress.iterrows(): 
        cursor.execute(insert_table_DeliveryAddress_sql, tuple(row)) 
        cnx.commit()
    print(i+1, "Rows were successfully recorded in the Table DeliveryAddress.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# 21000 Rows were successfully recorded in the Table DeliveryAddress.
# CPU times: total: 15.5 s
# Wall time: 20min 9s

# %%
# %%time

#Insert records into the Table Products
try:
    insert_table_Products_sql = """INSERT INTO little_lemon_org_database.Products VALUES (%s,%s,%s,%s,%s,%s,%s)""" 
    for i,row in df_Produts.iterrows(): 
        cursor.execute(insert_table_Products_sql, tuple(row)) 
        cnx.commit()
    print(i+1, "Rows were successfully recorded in the Table Products.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# 107 Rows were successfully recorded in the Table Products.
# CPU times: total: 31.2 ms
# Wall time: 4.22 s

# %%
# %%time

#Insert records into the Table Customers
try:
    insert_table_Customers_sql = """INSERT INTO little_lemon_org_database.Customers VALUES (%s,%s,%s)""" 
    for i,row in df_Customers.iterrows(): 
        cursor.execute(insert_table_Customers_sql, tuple(row)) 
        cnx.commit()
    print(i+1, "Rows were successfully recorded in the Table Customers.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# 1000 Rows were successfully recorded in the Table Customers.
# CPU times: total: 766 ms
# Wall time: 48 s

# %%
# %%time

#Insert records into the Table Orders
try:
    insert_table_Orders_sql = """INSERT INTO little_lemon_org_database.Orders VALUES (%s,%s,%s)""" 
    for i,row in df_Orders.iterrows(): 
        cursor.execute(insert_table_Orders_sql, tuple(row)) 
        cnx.commit()
    print(i+1, "Rows were successfully recorded in the Table Orders.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# 1000 Rows were successfully recorded in the Table Orders.
# CPU times: total: 594 ms
# Wall time: 53.4 s

# %%
# %%time

#Insert records into the Table OrderDetails
try:
    insert_table_OrderDetails_sql = """INSERT INTO little_lemon_org_database.OrderDetails(
                                            DeliveryDate, DeliveryCost, Quantity, CostPrice, 
                                            Discount, AddressID, OrderID, ProductID) 
                                            VALUES (%s,%s,%s,%s,%s,%s,%s,%s)""" 
    for i,row in df_OrderDetails.iterrows(): 
        cursor.execute(insert_table_OrderDetails_sql, tuple(row)) 
        cnx.commit()
    print(i+1, "Rows were successfully recorded in the Table OrderDetails.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# 21000 Rows were successfully recorded in the Table OrderDetails.
# CPU times: total: 17.3 s
# Wall time: 19min 30s

# %% [markdown]
# # Task 3: Create a stored procedure that returns the maximum quantity in an order.

# %%
#Stored Procedure GetMaxQuantity() that returns the maximum quantity in all orders
DropGetMaxQuantity_sql ="""DROP PROCEDURE IF EXISTS GetMaxQuantity;"""
GetMaxQuantity_sql = """CREATE PROCEDURE IF NOT EXISTS GetMaxQuantity (
    OUT MaxQuantity INT)
    BEGIN 
        SELECT MAX(Quantity)  
        FROM `orderdetails`
        INTO MaxQuantity;
    END"""

#Create the Stored Procedure
try:
    cursor.execute(DropGetMaxQuantity_sql) 
    cursor.execute(GetMaxQuantity_sql) 
    print("Procedure successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Procedure successfully created or already exists.

# %%
#Retrieve data from the Stored Procedure
args=['@MaxQuantity']

try:
    allResults=cursor.callproc('GetMaxQuantity', args)
    for eachResult in allResults:
        print('Maximum Quantity: ',eachResult)
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Maximum Quantity:  3

# %%
#Stored Procedure GetMaxQuantity() that returns the maximum quantity in an order
DropGetAllMaxQuantity_sql ="""DROP PROCEDURE IF EXISTS GetAllMaxQuantity;"""
GetAllMaxQuantity_sql ="""CREATE PROCEDURE IF NOT EXISTS GetAllMaxQuantity ()
    BEGIN 
        SELECT OrderID, MAX(Quantity) AS 'Max Quantity' 
        FROM `orderdetails` 
        GROUP BY OrderID;
    END"""

#Create the Stored Procedure
try:
    cursor.execute(DropGetAllMaxQuantity_sql) 
    cursor.execute(GetAllMaxQuantity_sql) 
    print("Procedure successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Procedure successfully created or already exists.

# %%
#Retrieve data from the Stored Procedure
try:
    cursor.callproc('GetAllMaxQuantity')
    allResults=[]
    for eachResult in cursor.stored_results():
        ds = eachResult.fetchall()
        i=1
        for eachResult in ds:
            print('Result #', i, "- OrderID: ",eachResult[0],"- Quantity: ",eachResult[1])
            i=i+1
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Result # 1 - OrderID:  00-008-3271 - Quantity:  2
# Result # 2 - OrderID:  00-283-3544 - Quantity:  2
# Result # 3 - OrderID:  00-350-1396 - Quantity:  1
# Result # 4 - OrderID:  00-451-8857 - Quantity:  1
# Result # 5 - OrderID:  00-465-7031 - Quantity:  3
# Result # 6 - OrderID:  00-618-9205 - Quantity:  3
# Result # 7 - OrderID:  00-669-6040 - Quantity:  2
# Result # 8 - OrderID:  00-799-3091 - Quantity:  3
# Result # 9 - OrderID:  00-822-8333 - Quantity:  3
# Result # 10 - OrderID:  00-965-9450 - Quantity:  2
# Result # 11 - OrderID:  01-062-3384 - Quantity:  1
# Result # 12 - OrderID:  01-423-8434 - Quantity:  3
# Result # 13 - OrderID:  01-715-3869 - Quantity:  3
# Result # 14 - OrderID:  01-733-5889 - Quantity:  1
# Result # 15 - OrderID:  01-754-7255 - Quantity:  2
# Result # 16 - OrderID:  01-855-8188 - Quantity:  3
# Result # 17 - OrderID:  01-877-6020 - Quantity:  2
# Result # 18 - OrderID:  01-879-8004 - Quantity:  3
# Result # 19 - OrderID:  01-975-7149 - Quantity:  3
# Result # 20 - OrderID:  01-981-5069 - Quantity:  2
# Result # 21 - OrderID:  02-211-2785 - Quantity:  3
# Result # 22 - OrderID:  02-266-1313 - Quantity:  2
# Result # 23 - OrderID:  02-311-4674 - Quantity:  1
# Result # 24 - OrderID:  02-569-3156 - Quantity:  1
# Result # 25 - OrderID:  02-699-8406 - Quantity:  2
# Result # 26 - OrderID:  02-715-2965 - Quantity:  3
# Result # 27 - OrderID:  02-732-6800 - Quantity:  3
# Result # 28 - OrderID:  02-938-1657 - Quantity:  1
# Result # 29 - OrderID:  03-039-5845 - Quantity:  3
# Result # 30 - OrderID:  03-132-2890 - Quantity:  2
# Result # 31 - OrderID:  03-248-8148 - Quantity:  1
# Result # 32 - OrderID:  03-297-4257 - Quantity:  2
# Result # 33 - OrderID:  03-464-8128 - Quantity:  3
# Result # 34 - OrderID:  03-555-7951 - Quantity:  2
# Result # 35 - OrderID:  03-568-8174 - Quantity:  2
# Result # 36 - OrderID:  03-825-5219 - Quantity:  2
# Result # 37 - OrderID:  03-893-8767 - Quantity:  1
# Result # 38 - OrderID:  03-955-4532 - Quantity:  1
# Result # 39 - OrderID:  04-003-4647 - Quantity:  2
# Result # 40 - OrderID:  04-238-9179 - Quantity:  1
# Result # 41 - OrderID:  04-546-8049 - Quantity:  2
# Result # 42 - OrderID:  04-743-8019 - Quantity:  1
# Result # 43 - OrderID:  04-812-8753 - Quantity:  2
# Result # 44 - OrderID:  04-904-4552 - Quantity:  2
# Result # 45 - OrderID:  04-911-6551 - Quantity:  2
# Result # 46 - OrderID:  04-976-7880 - Quantity:  2
# Result # 47 - OrderID:  05-024-1112 - Quantity:  3
# Result # 48 - OrderID:  05-318-1801 - Quantity:  1
# Result # 49 - OrderID:  05-378-2914 - Quantity:  2
# Result # 50 - OrderID:  05-410-4163 - Quantity:  3
# Result # 51 - OrderID:  05-822-0829 - Quantity:  1
# Result # 52 - OrderID:  05-825-9260 - Quantity:  1
# Result # 53 - OrderID:  05-971-9045 - Quantity:  2
# Result # 54 - OrderID:  05-982-4967 - Quantity:  2
# Result # 55 - OrderID:  06-075-0174 - Quantity:  3
# Result # 56 - OrderID:  06-416-0671 - Quantity:  2
# Result # 57 - OrderID:  06-457-9925 - Quantity:  1
# Result # 58 - OrderID:  06-605-4865 - Quantity:  2
# Result # 59 - OrderID:  06-705-6026 - Quantity:  3
# Result # 60 - OrderID:  06-887-6332 - Quantity:  3
# Result # 61 - OrderID:  06-934-9396 - Quantity:  2
# Result # 62 - OrderID:  07-113-3748 - Quantity:  3
# Result # 63 - OrderID:  07-116-3515 - Quantity:  2
# Result # 64 - OrderID:  07-143-9471 - Quantity:  2
# Result # 65 - OrderID:  07-244-2129 - Quantity:  2
# Result # 66 - OrderID:  07-275-2696 - Quantity:  1
# Result # 67 - OrderID:  07-312-6026 - Quantity:  2
# Result # 68 - OrderID:  07-322-4153 - Quantity:  3
# Result # 69 - OrderID:  07-634-6294 - Quantity:  2
# Result # 70 - OrderID:  07-808-6932 - Quantity:  1
# Result # 71 - OrderID:  08-152-8962 - Quantity:  2
# Result # 72 - OrderID:  08-270-7581 - Quantity:  2
# Result # 73 - OrderID:  08-309-3649 - Quantity:  3
# Result # 74 - OrderID:  08-316-6754 - Quantity:  2
# Result # 75 - OrderID:  08-483-5677 - Quantity:  3
# Result # 76 - OrderID:  08-659-6030 - Quantity:  2
# Result # 77 - OrderID:  08-660-0159 - Quantity:  1
# Result # 78 - OrderID:  08-855-8354 - Quantity:  1
# Result # 79 - OrderID:  08-940-9111 - Quantity:  3
# Result # 80 - OrderID:  09-019-6593 - Quantity:  3
# Result # 81 - OrderID:  09-058-1844 - Quantity:  3
# Result # 82 - OrderID:  09-185-3204 - Quantity:  1
# Result # 83 - OrderID:  09-229-1754 - Quantity:  3
# Result # 84 - OrderID:  09-440-5820 - Quantity:  2
# Result # 85 - OrderID:  09-481-5023 - Quantity:  3
# Result # 86 - OrderID:  09-522-5385 - Quantity:  3
# Result # 87 - OrderID:  09-896-5300 - Quantity:  2
# Result # 88 - OrderID:  09-923-6077 - Quantity:  3
# Result # 89 - OrderID:  10-030-5503 - Quantity:  2
# Result # 90 - OrderID:  10-052-8149 - Quantity:  2
# Result # 91 - OrderID:  10-120-0016 - Quantity:  1
# Result # 92 - OrderID:  10-141-0121 - Quantity:  3
# Result # 93 - OrderID:  10-150-2658 - Quantity:  1
# Result # 94 - OrderID:  10-370-7784 - Quantity:  2
# Result # 95 - OrderID:  10-390-3471 - Quantity:  2
# Result # 96 - OrderID:  10-462-2908 - Quantity:  2
# Result # 97 - OrderID:  10-621-7662 - Quantity:  1
# Result # 98 - OrderID:  10-638-5334 - Quantity:  1
# Result # 99 - OrderID:  10-814-8054 - Quantity:  2
# Result # 100 - OrderID:  11-146-3342 - Quantity:  2
# Result # 101 - OrderID:  11-244-2193 - Quantity:  3
# Result # 102 - OrderID:  11-397-2150 - Quantity:  3
# Result # 103 - OrderID:  11-446-2659 - Quantity:  3
# Result # 104 - OrderID:  11-463-8439 - Quantity:  1
# Result # 105 - OrderID:  11-486-8739 - Quantity:  1
# Result # 106 - OrderID:  11-645-0948 - Quantity:  2
# Result # 107 - OrderID:  11-648-9765 - Quantity:  2
# Result # 108 - OrderID:  11-700-3520 - Quantity:  2
# Result # 109 - OrderID:  11-741-2205 - Quantity:  1
# Result # 110 - OrderID:  11-769-7584 - Quantity:  3
# Result # 111 - OrderID:  11-776-8532 - Quantity:  1
# Result # 112 - OrderID:  11-821-0545 - Quantity:  2
# Result # 113 - OrderID:  11-835-2932 - Quantity:  3
# Result # 114 - OrderID:  11-858-8042 - Quantity:  1
# Result # 115 - OrderID:  11-997-6382 - Quantity:  3
# Result # 116 - OrderID:  12-128-2576 - Quantity:  3
# Result # 117 - OrderID:  12-306-6646 - Quantity:  2
# Result # 118 - OrderID:  12-346-4013 - Quantity:  2
# Result # 119 - OrderID:  12-371-9369 - Quantity:  3
# Result # 120 - OrderID:  12-605-1676 - Quantity:  2
# Result # 121 - OrderID:  12-648-4718 - Quantity:  2
# Result # 122 - OrderID:  12-718-1501 - Quantity:  3
# Result # 123 - OrderID:  12-837-0577 - Quantity:  2
# Result # 124 - OrderID:  13-018-1111 - Quantity:  3
# Result # 125 - OrderID:  13-189-4080 - Quantity:  2
# Result # 126 - OrderID:  13-235-5773 - Quantity:  1
# Result # 127 - OrderID:  13-435-8115 - Quantity:  2
# Result # 128 - OrderID:  13-469-9343 - Quantity:  2
# Result # 129 - OrderID:  13-555-4988 - Quantity:  2
# Result # 130 - OrderID:  13-673-8989 - Quantity:  1
# Result # 131 - OrderID:  13-698-5271 - Quantity:  3
# Result # 132 - OrderID:  13-912-7109 - Quantity:  2
# Result # 133 - OrderID:  14-210-2413 - Quantity:  3
# Result # 134 - OrderID:  14-224-3137 - Quantity:  2
# Result # 135 - OrderID:  14-316-4950 - Quantity:  1
# Result # 136 - OrderID:  14-376-2485 - Quantity:  3
# Result # 137 - OrderID:  14-606-3655 - Quantity:  1
# Result # 138 - OrderID:  14-648-5507 - Quantity:  2
# Result # 139 - OrderID:  15-090-5294 - Quantity:  1
# Result # 140 - OrderID:  15-190-8465 - Quantity:  2
# Result # 141 - OrderID:  15-192-4862 - Quantity:  1
# Result # 142 - OrderID:  15-197-3569 - Quantity:  1
# Result # 143 - OrderID:  15-260-9895 - Quantity:  3
# Result # 144 - OrderID:  15-272-2116 - Quantity:  2
# Result # 145 - OrderID:  15-297-7741 - Quantity:  2
# Result # 146 - OrderID:  15-307-8168 - Quantity:  1
# Result # 147 - OrderID:  15-663-0481 - Quantity:  1
# Result # 148 - OrderID:  15-667-9235 - Quantity:  2
# Result # 149 - OrderID:  16-386-7757 - Quantity:  3
# Result # 150 - OrderID:  16-609-1782 - Quantity:  3
# Result # 151 - OrderID:  16-921-7992 - Quantity:  3
# Result # 152 - OrderID:  16-946-9856 - Quantity:  1
# Result # 153 - OrderID:  17-146-9681 - Quantity:  3
# Result # 154 - OrderID:  17-253-1197 - Quantity:  2
# Result # 155 - OrderID:  17-264-8555 - Quantity:  3
# Result # 156 - OrderID:  17-396-0834 - Quantity:  2
# Result # 157 - OrderID:  17-529-1692 - Quantity:  1
# Result # 158 - OrderID:  17-586-7905 - Quantity:  2
# Result # 159 - OrderID:  17-708-5350 - Quantity:  3
# Result # 160 - OrderID:  17-851-5705 - Quantity:  2
# Result # 161 - OrderID:  18-136-6969 - Quantity:  3
# Result # 162 - OrderID:  18-237-6374 - Quantity:  2
# Result # 163 - OrderID:  18-252-1922 - Quantity:  1
# Result # 164 - OrderID:  18-359-3465 - Quantity:  1
# Result # 165 - OrderID:  18-752-8277 - Quantity:  2
# Result # 166 - OrderID:  18-944-2420 - Quantity:  2
# Result # 167 - OrderID:  19-156-3010 - Quantity:  3
# Result # 168 - OrderID:  19-189-3064 - Quantity:  3
# Result # 169 - OrderID:  19-281-5590 - Quantity:  3
# Result # 170 - OrderID:  19-329-8137 - Quantity:  2
# Result # 171 - OrderID:  19-522-8580 - Quantity:  1
# Result # 172 - OrderID:  19-530-8425 - Quantity:  2
# Result # 173 - OrderID:  19-560-5489 - Quantity:  2
# Result # 174 - OrderID:  19-768-2646 - Quantity:  3
# Result # 175 - OrderID:  19-798-0585 - Quantity:  3
# Result # 176 - OrderID:  19-953-6477 - Quantity:  1
# Result # 177 - OrderID:  20-140-3398 - Quantity:  2
# Result # 178 - OrderID:  20-205-9814 - Quantity:  2
# Result # 179 - OrderID:  20-343-7160 - Quantity:  2
# Result # 180 - OrderID:  20-698-8725 - Quantity:  1
# Result # 181 - OrderID:  21-039-2999 - Quantity:  3
# Result # 182 - OrderID:  21-104-5976 - Quantity:  3
# Result # 183 - OrderID:  21-106-4079 - Quantity:  2
# Result # 184 - OrderID:  21-164-7722 - Quantity:  2
# Result # 185 - OrderID:  21-385-2808 - Quantity:  2
# Result # 186 - OrderID:  21-627-1027 - Quantity:  2
# Result # 187 - OrderID:  21-743-3530 - Quantity:  3
# Result # 188 - OrderID:  21-844-2539 - Quantity:  2
# Result # 189 - OrderID:  22-001-6016 - Quantity:  3
# Result # 190 - OrderID:  22-130-4513 - Quantity:  3
# Result # 191 - OrderID:  22-401-7510 - Quantity:  3
# Result # 192 - OrderID:  22-437-6211 - Quantity:  2
# Result # 193 - OrderID:  22-501-9215 - Quantity:  3
# Result # 194 - OrderID:  22-561-9916 - Quantity:  2
# Result # 195 - OrderID:  22-572-6325 - Quantity:  1
# Result # 196 - OrderID:  22-697-0930 - Quantity:  3
# Result # 197 - OrderID:  22-867-9098 - Quantity:  3
# Result # 198 - OrderID:  22-872-7952 - Quantity:  1
# Result # 199 - OrderID:  22-904-5860 - Quantity:  3
# Result # 200 - OrderID:  22-906-5872 - Quantity:  3
# Result # 201 - OrderID:  23-082-1065 - Quantity:  3
# Result # 202 - OrderID:  23-153-9991 - Quantity:  3
# Result # 203 - OrderID:  23-364-4571 - Quantity:  2
# Result # 204 - OrderID:  23-382-0687 - Quantity:  2
# Result # 205 - OrderID:  23-427-8106 - Quantity:  3
# Result # 206 - OrderID:  23-582-1221 - Quantity:  3
# Result # 207 - OrderID:  23-636-0824 - Quantity:  1
# Result # 208 - OrderID:  23-760-0421 - Quantity:  2
# Result # 209 - OrderID:  23-824-2201 - Quantity:  3
# Result # 210 - OrderID:  23-898-9055 - Quantity:  3
# Result # 211 - OrderID:  24-041-3369 - Quantity:  1
# Result # 212 - OrderID:  24-102-1793 - Quantity:  2
# Result # 213 - OrderID:  24-139-0192 - Quantity:  3
# Result # 214 - OrderID:  24-314-4867 - Quantity:  3
# Result # 215 - OrderID:  24-332-5305 - Quantity:  2
# Result # 216 - OrderID:  24-339-0545 - Quantity:  3
# Result # 217 - OrderID:  24-351-9777 - Quantity:  2
# Result # 218 - OrderID:  24-502-2774 - Quantity:  3
# Result # 219 - OrderID:  24-678-5042 - Quantity:  3
# Result # 220 - OrderID:  24-690-6396 - Quantity:  1
# Result # 221 - OrderID:  24-714-2660 - Quantity:  1
# Result # 222 - OrderID:  24-934-3291 - Quantity:  3
# Result # 223 - OrderID:  24-998-9967 - Quantity:  2
# Result # 224 - OrderID:  25-093-8535 - Quantity:  3
# Result # 225 - OrderID:  25-177-6985 - Quantity:  3
# Result # 226 - OrderID:  25-252-0068 - Quantity:  2
# Result # 227 - OrderID:  25-339-5566 - Quantity:  3
# Result # 228 - OrderID:  25-432-8239 - Quantity:  2
# Result # 229 - OrderID:  25-433-9492 - Quantity:  2
# Result # 230 - OrderID:  25-485-3794 - Quantity:  1
# Result # 231 - OrderID:  25-522-2006 - Quantity:  2
# Result # 232 - OrderID:  25-621-0618 - Quantity:  3
# Result # 233 - OrderID:  25-771-0744 - Quantity:  2
# Result # 234 - OrderID:  25-850-5723 - Quantity:  2
# Result # 235 - OrderID:  25-912-8989 - Quantity:  3
# Result # 236 - OrderID:  26-231-8897 - Quantity:  3
# Result # 237 - OrderID:  26-281-8125 - Quantity:  3
# Result # 238 - OrderID:  26-326-8254 - Quantity:  2
# Result # 239 - OrderID:  26-437-6628 - Quantity:  1
# Result # 240 - OrderID:  26-461-5577 - Quantity:  3
# Result # 241 - OrderID:  26-802-1005 - Quantity:  2
# Result # 242 - OrderID:  26-929-8429 - Quantity:  1
# Result # 243 - OrderID:  26-973-3455 - Quantity:  2
# Result # 244 - OrderID:  27-077-0389 - Quantity:  2
# Result # 245 - OrderID:  27-252-7456 - Quantity:  3
# Result # 246 - OrderID:  27-295-8802 - Quantity:  3
# Result # 247 - OrderID:  27-600-6800 - Quantity:  3
# Result # 248 - OrderID:  27-774-9457 - Quantity:  3
# Result # 249 - OrderID:  27-991-7078 - Quantity:  1
# Result # 250 - OrderID:  28-019-1318 - Quantity:  1
# Result # 251 - OrderID:  28-279-3419 - Quantity:  2
# Result # 252 - OrderID:  28-341-5469 - Quantity:  3
# Result # 253 - OrderID:  28-376-6551 - Quantity:  3
# Result # 254 - OrderID:  28-387-3547 - Quantity:  2
# Result # 255 - OrderID:  28-608-5137 - Quantity:  3
# Result # 256 - OrderID:  28-703-1952 - Quantity:  1
# Result # 257 - OrderID:  28-882-5933 - Quantity:  2
# Result # 258 - OrderID:  28-960-2783 - Quantity:  2
# Result # 259 - OrderID:  29-260-4008 - Quantity:  1
# Result # 260 - OrderID:  29-353-4988 - Quantity:  2
# Result # 261 - OrderID:  29-463-3688 - Quantity:  1
# Result # 262 - OrderID:  29-546-8618 - Quantity:  3
# Result # 263 - OrderID:  29-577-3059 - Quantity:  3
# Result # 264 - OrderID:  29-587-2527 - Quantity:  3
# Result # 265 - OrderID:  29-595-2468 - Quantity:  1
# Result # 266 - OrderID:  29-600-4791 - Quantity:  3
# Result # 267 - OrderID:  29-600-8355 - Quantity:  1
# Result # 268 - OrderID:  29-601-2712 - Quantity:  3
# Result # 269 - OrderID:  29-728-2837 - Quantity:  1
# Result # 270 - OrderID:  29-773-5797 - Quantity:  3
# Result # 271 - OrderID:  29-930-1681 - Quantity:  2
# Result # 272 - OrderID:  29-947-3866 - Quantity:  2
# Result # 273 - OrderID:  29-952-5748 - Quantity:  2
# Result # 274 - OrderID:  30-032-8406 - Quantity:  3
# Result # 275 - OrderID:  30-082-2867 - Quantity:  2
# Result # 276 - OrderID:  30-087-5181 - Quantity:  1
# Result # 277 - OrderID:  30-117-6174 - Quantity:  3
# Result # 278 - OrderID:  30-124-4774 - Quantity:  3
# Result # 279 - OrderID:  30-148-2955 - Quantity:  1
# Result # 280 - OrderID:  30-205-9759 - Quantity:  3
# Result # 281 - OrderID:  30-418-5129 - Quantity:  1
# Result # 282 - OrderID:  30-601-0133 - Quantity:  3
# Result # 283 - OrderID:  30-715-2573 - Quantity:  3
# Result # 284 - OrderID:  30-724-0380 - Quantity:  2
# Result # 285 - OrderID:  30-790-3083 - Quantity:  3
# Result # 286 - OrderID:  30-791-3047 - Quantity:  2
# Result # 287 - OrderID:  30-867-3284 - Quantity:  2
# Result # 288 - OrderID:  30-969-9125 - Quantity:  2
# Result # 289 - OrderID:  31-014-4239 - Quantity:  2
# Result # 290 - OrderID:  31-073-7194 - Quantity:  2
# Result # 291 - OrderID:  31-087-9491 - Quantity:  1
# Result # 292 - OrderID:  31-106-2180 - Quantity:  1
# Result # 293 - OrderID:  31-121-8822 - Quantity:  3
# Result # 294 - OrderID:  31-221-4991 - Quantity:  2
# Result # 295 - OrderID:  31-255-9487 - Quantity:  1
# Result # 296 - OrderID:  31-302-3952 - Quantity:  3
# Result # 297 - OrderID:  31-340-1373 - Quantity:  3
# Result # 298 - OrderID:  31-404-5047 - Quantity:  1
# Result # 299 - OrderID:  31-405-1090 - Quantity:  3
# Result # 300 - OrderID:  31-576-8678 - Quantity:  2
# Result # 301 - OrderID:  31-593-0632 - Quantity:  3
# Result # 302 - OrderID:  31-607-0351 - Quantity:  1
# Result # 303 - OrderID:  31-669-5161 - Quantity:  2
# Result # 304 - OrderID:  31-762-1168 - Quantity:  1
# Result # 305 - OrderID:  31-807-7846 - Quantity:  1
# Result # 306 - OrderID:  31-955-7364 - Quantity:  3
# Result # 307 - OrderID:  32-023-4917 - Quantity:  1
# Result # 308 - OrderID:  32-049-4417 - Quantity:  2
# Result # 309 - OrderID:  32-208-6721 - Quantity:  2
# Result # 310 - OrderID:  32-317-3692 - Quantity:  1
# Result # 311 - OrderID:  32-377-0706 - Quantity:  3
# Result # 312 - OrderID:  32-483-3668 - Quantity:  1
# Result # 313 - OrderID:  32-596-3017 - Quantity:  3
# Result # 314 - OrderID:  32-698-1958 - Quantity:  3
# Result # 315 - OrderID:  32-732-9550 - Quantity:  2
# Result # 316 - OrderID:  32-783-7159 - Quantity:  1
# Result # 317 - OrderID:  32-792-5231 - Quantity:  2
# Result # 318 - OrderID:  32-923-9697 - Quantity:  1
# Result # 319 - OrderID:  33-044-7954 - Quantity:  3
# Result # 320 - OrderID:  33-177-2796 - Quantity:  1
# Result # 321 - OrderID:  33-207-9048 - Quantity:  1
# Result # 322 - OrderID:  33-294-7116 - Quantity:  3
# Result # 323 - OrderID:  33-390-5032 - Quantity:  3
# Result # 324 - OrderID:  33-395-8454 - Quantity:  2
# Result # 325 - OrderID:  33-541-8718 - Quantity:  3
# Result # 326 - OrderID:  33-583-4747 - Quantity:  1
# Result # 327 - OrderID:  33-596-6321 - Quantity:  1
# Result # 328 - OrderID:  33-667-2660 - Quantity:  2
# Result # 329 - OrderID:  33-671-4773 - Quantity:  3
# Result # 330 - OrderID:  33-755-4654 - Quantity:  2
# Result # 331 - OrderID:  33-894-6676 - Quantity:  3
# Result # 332 - OrderID:  33-930-0109 - Quantity:  1
# Result # 333 - OrderID:  34-061-0340 - Quantity:  3
# Result # 334 - OrderID:  34-230-0439 - Quantity:  1
# Result # 335 - OrderID:  34-257-0115 - Quantity:  2
# Result # 336 - OrderID:  34-331-6365 - Quantity:  2
# Result # 337 - OrderID:  34-415-8074 - Quantity:  2
# Result # 338 - OrderID:  34-426-9335 - Quantity:  2
# Result # 339 - OrderID:  34-629-9123 - Quantity:  2
# Result # 340 - OrderID:  34-631-7695 - Quantity:  2
# Result # 341 - OrderID:  34-970-4387 - Quantity:  2
# Result # 342 - OrderID:  35-067-3364 - Quantity:  2
# Result # 343 - OrderID:  35-174-3155 - Quantity:  2
# Result # 344 - OrderID:  35-326-1148 - Quantity:  3
# Result # 345 - OrderID:  35-371-2486 - Quantity:  2
# Result # 346 - OrderID:  35-427-7418 - Quantity:  3
# Result # 347 - OrderID:  35-460-4013 - Quantity:  1
# Result # 348 - OrderID:  35-587-5940 - Quantity:  3
# Result # 349 - OrderID:  35-759-1971 - Quantity:  1
# Result # 350 - OrderID:  35-795-9456 - Quantity:  2
# Result # 351 - OrderID:  35-884-9148 - Quantity:  3
# Result # 352 - OrderID:  35-907-6473 - Quantity:  2
# Result # 353 - OrderID:  35-988-0040 - Quantity:  3
# Result # 354 - OrderID:  36-019-1520 - Quantity:  2
# Result # 355 - OrderID:  36-290-7816 - Quantity:  2
# Result # 356 - OrderID:  36-383-1600 - Quantity:  2
# Result # 357 - OrderID:  36-478-2126 - Quantity:  2
# Result # 358 - OrderID:  36-480-1277 - Quantity:  2
# Result # 359 - OrderID:  36-505-9404 - Quantity:  2
# Result # 360 - OrderID:  36-779-8330 - Quantity:  3
# Result # 361 - OrderID:  36-816-5383 - Quantity:  3
# Result # 362 - OrderID:  36-898-0004 - Quantity:  3
# Result # 363 - OrderID:  36-917-2834 - Quantity:  3
# Result # 364 - OrderID:  36-928-2921 - Quantity:  2
# Result # 365 - OrderID:  37-082-5374 - Quantity:  2
# Result # 366 - OrderID:  37-103-3005 - Quantity:  3
# Result # 367 - OrderID:  37-255-6435 - Quantity:  3
# Result # 368 - OrderID:  37-273-5241 - Quantity:  3
# Result # 369 - OrderID:  37-398-9630 - Quantity:  2
# Result # 370 - OrderID:  37-474-6061 - Quantity:  2
# Result # 371 - OrderID:  37-563-3518 - Quantity:  1
# Result # 372 - OrderID:  37-656-4777 - Quantity:  3
# Result # 373 - OrderID:  37-675-7898 - Quantity:  3
# Result # 374 - OrderID:  37-691-9097 - Quantity:  1
# Result # 375 - OrderID:  37-765-3279 - Quantity:  1
# Result # 376 - OrderID:  38-068-6643 - Quantity:  1
# Result # 377 - OrderID:  38-295-3172 - Quantity:  3
# Result # 378 - OrderID:  38-478-1265 - Quantity:  3
# Result # 379 - OrderID:  38-624-7763 - Quantity:  2
# Result # 380 - OrderID:  38-694-5330 - Quantity:  3
# Result # 381 - OrderID:  38-750-7959 - Quantity:  1
# Result # 382 - OrderID:  38-969-7419 - Quantity:  1
# Result # 383 - OrderID:  38-994-1709 - Quantity:  1
# Result # 384 - OrderID:  39-040-2440 - Quantity:  2
# Result # 385 - OrderID:  39-130-1094 - Quantity:  2
# Result # 386 - OrderID:  39-201-1204 - Quantity:  3
# Result # 387 - OrderID:  39-547-3173 - Quantity:  1
# Result # 388 - OrderID:  39-607-8115 - Quantity:  1
# Result # 389 - OrderID:  39-613-0627 - Quantity:  2
# Result # 390 - OrderID:  39-647-4894 - Quantity:  2
# Result # 391 - OrderID:  39-843-1059 - Quantity:  2
# Result # 392 - OrderID:  40-081-7496 - Quantity:  3
# Result # 393 - OrderID:  40-107-4974 - Quantity:  3
# Result # 394 - OrderID:  40-168-4233 - Quantity:  3
# Result # 395 - OrderID:  40-192-8164 - Quantity:  3
# Result # 396 - OrderID:  40-278-4324 - Quantity:  2
# Result # 397 - OrderID:  40-429-8594 - Quantity:  3
# Result # 398 - OrderID:  40-476-8892 - Quantity:  3
# Result # 399 - OrderID:  40-486-8511 - Quantity:  3
# Result # 400 - OrderID:  40-599-5065 - Quantity:  2
# Result # 401 - OrderID:  40-690-8134 - Quantity:  1
# Result # 402 - OrderID:  40-708-8263 - Quantity:  3
# Result # 403 - OrderID:  40-864-0766 - Quantity:  2
# Result # 404 - OrderID:  41-177-5682 - Quantity:  1
# Result # 405 - OrderID:  41-179-7445 - Quantity:  1
# Result # 406 - OrderID:  41-201-7265 - Quantity:  2
# Result # 407 - OrderID:  41-269-9772 - Quantity:  2
# Result # 408 - OrderID:  41-328-2835 - Quantity:  3
# Result # 409 - OrderID:  41-441-3097 - Quantity:  2
# Result # 410 - OrderID:  41-597-5931 - Quantity:  3
# Result # 411 - OrderID:  41-622-4465 - Quantity:  2
# Result # 412 - OrderID:  41-640-4815 - Quantity:  1
# Result # 413 - OrderID:  42-108-2633 - Quantity:  2
# Result # 414 - OrderID:  42-108-7287 - Quantity:  3
# Result # 415 - OrderID:  42-250-4316 - Quantity:  1
# Result # 416 - OrderID:  42-303-1476 - Quantity:  1
# Result # 417 - OrderID:  42-438-0394 - Quantity:  1
# Result # 418 - OrderID:  42-829-4772 - Quantity:  3
# Result # 419 - OrderID:  42-906-2475 - Quantity:  3
# Result # 420 - OrderID:  43-009-8040 - Quantity:  2
# Result # 421 - OrderID:  43-052-9931 - Quantity:  2
# Result # 422 - OrderID:  43-109-7017 - Quantity:  2
# Result # 423 - OrderID:  43-134-2893 - Quantity:  1
# Result # 424 - OrderID:  43-238-0006 - Quantity:  1
# Result # 425 - OrderID:  43-461-0935 - Quantity:  1
# Result # 426 - OrderID:  43-566-9850 - Quantity:  3
# Result # 427 - OrderID:  43-634-6121 - Quantity:  3
# Result # 428 - OrderID:  43-663-3135 - Quantity:  2
# Result # 429 - OrderID:  43-718-3224 - Quantity:  1
# Result # 430 - OrderID:  43-720-3267 - Quantity:  3
# Result # 431 - OrderID:  43-799-4873 - Quantity:  2
# Result # 432 - OrderID:  43-850-7830 - Quantity:  3
# Result # 433 - OrderID:  43-918-0203 - Quantity:  3
# Result # 434 - OrderID:  44-087-0146 - Quantity:  2
# Result # 435 - OrderID:  44-357-1100 - Quantity:  1
# Result # 436 - OrderID:  44-379-6825 - Quantity:  3
# Result # 437 - OrderID:  44-439-4440 - Quantity:  2
# Result # 438 - OrderID:  44-701-3012 - Quantity:  2
# Result # 439 - OrderID:  44-877-6595 - Quantity:  2
# Result # 440 - OrderID:  44-969-2805 - Quantity:  3
# Result # 441 - OrderID:  45-033-9684 - Quantity:  3
# Result # 442 - OrderID:  45-043-4851 - Quantity:  2
# Result # 443 - OrderID:  45-153-3592 - Quantity:  2
# Result # 444 - OrderID:  45-381-3607 - Quantity:  1
# Result # 445 - OrderID:  45-436-6764 - Quantity:  3
# Result # 446 - OrderID:  45-486-4534 - Quantity:  2
# Result # 447 - OrderID:  45-519-3808 - Quantity:  2
# Result # 448 - OrderID:  45-594-5624 - Quantity:  1
# Result # 449 - OrderID:  45-742-2253 - Quantity:  1
# Result # 450 - OrderID:  45-780-6744 - Quantity:  3
# Result # 451 - OrderID:  45-989-0711 - Quantity:  3
# Result # 452 - OrderID:  46-031-2472 - Quantity:  2
# Result # 453 - OrderID:  46-072-3557 - Quantity:  3
# Result # 454 - OrderID:  46-138-6582 - Quantity:  2
# Result # 455 - OrderID:  46-301-6761 - Quantity:  3
# Result # 456 - OrderID:  46-576-0301 - Quantity:  2
# Result # 457 - OrderID:  46-627-8981 - Quantity:  3
# Result # 458 - OrderID:  46-671-2432 - Quantity:  3
# Result # 459 - OrderID:  46-686-0158 - Quantity:  1
# Result # 460 - OrderID:  46-715-1183 - Quantity:  1
# Result # 461 - OrderID:  46-773-9492 - Quantity:  3
# Result # 462 - OrderID:  46-796-5628 - Quantity:  3
# Result # 463 - OrderID:  46-892-9399 - Quantity:  3
# Result # 464 - OrderID:  46-969-1933 - Quantity:  2
# Result # 465 - OrderID:  47-068-1396 - Quantity:  2
# Result # 466 - OrderID:  47-084-5361 - Quantity:  3
# Result # 467 - OrderID:  47-102-5062 - Quantity:  3
# Result # 468 - OrderID:  47-198-9429 - Quantity:  1
# Result # 469 - OrderID:  47-441-1628 - Quantity:  3
# Result # 470 - OrderID:  47-612-6340 - Quantity:  3
# Result # 471 - OrderID:  47-760-3761 - Quantity:  1
# Result # 472 - OrderID:  47-940-7720 - Quantity:  3
# Result # 473 - OrderID:  48-335-5237 - Quantity:  1
# Result # 474 - OrderID:  48-370-5933 - Quantity:  2
# Result # 475 - OrderID:  48-873-2607 - Quantity:  3
# Result # 476 - OrderID:  49-275-9191 - Quantity:  1
# Result # 477 - OrderID:  49-337-9727 - Quantity:  2
# Result # 478 - OrderID:  49-366-5985 - Quantity:  1
# Result # 479 - OrderID:  49-368-5121 - Quantity:  3
# Result # 480 - OrderID:  49-404-6008 - Quantity:  1
# Result # 481 - OrderID:  49-429-0115 - Quantity:  1
# Result # 482 - OrderID:  49-795-0099 - Quantity:  2
# Result # 483 - OrderID:  49-841-5624 - Quantity:  2
# Result # 484 - OrderID:  49-934-7149 - Quantity:  1
# Result # 485 - OrderID:  49-961-9885 - Quantity:  3
# Result # 486 - OrderID:  50-030-7130 - Quantity:  3
# Result # 487 - OrderID:  50-048-3933 - Quantity:  2
# Result # 488 - OrderID:  50-185-4137 - Quantity:  2
# Result # 489 - OrderID:  50-370-8158 - Quantity:  1
# Result # 490 - OrderID:  50-475-9958 - Quantity:  3
# Result # 491 - OrderID:  50-617-3367 - Quantity:  2
# Result # 492 - OrderID:  50-696-6686 - Quantity:  1
# Result # 493 - OrderID:  50-747-1156 - Quantity:  3
# Result # 494 - OrderID:  50-817-8023 - Quantity:  1
# Result # 495 - OrderID:  50-818-0337 - Quantity:  1
# Result # 496 - OrderID:  51-007-0849 - Quantity:  2
# Result # 497 - OrderID:  51-062-8739 - Quantity:  2
# Result # 498 - OrderID:  51-247-0503 - Quantity:  2
# Result # 499 - OrderID:  51-287-9364 - Quantity:  3
# Result # 500 - OrderID:  51-290-4538 - Quantity:  1
# Result # 501 - OrderID:  51-322-7429 - Quantity:  2
# Result # 502 - OrderID:  51-349-8226 - Quantity:  3
# Result # 503 - OrderID:  51-420-8292 - Quantity:  3
# Result # 504 - OrderID:  51-470-5294 - Quantity:  1
# Result # 505 - OrderID:  51-493-6866 - Quantity:  3
# Result # 506 - OrderID:  51-955-2727 - Quantity:  1
# Result # 507 - OrderID:  51-959-4742 - Quantity:  1
# Result # 508 - OrderID:  51-960-7680 - Quantity:  1
# Result # 509 - OrderID:  52-071-2704 - Quantity:  3
# Result # 510 - OrderID:  52-104-3482 - Quantity:  1
# Result # 511 - OrderID:  52-152-3371 - Quantity:  3
# Result # 512 - OrderID:  52-348-6923 - Quantity:  2
# Result # 513 - OrderID:  52-523-5327 - Quantity:  2
# Result # 514 - OrderID:  52-708-9153 - Quantity:  1
# Result # 515 - OrderID:  52-905-6091 - Quantity:  2
# Result # 516 - OrderID:  52-984-2592 - Quantity:  1
# Result # 517 - OrderID:  53-068-3680 - Quantity:  3
# Result # 518 - OrderID:  53-131-0339 - Quantity:  1
# Result # 519 - OrderID:  53-322-3671 - Quantity:  2
# Result # 520 - OrderID:  53-401-6179 - Quantity:  3
# Result # 521 - OrderID:  53-412-8787 - Quantity:  2
# Result # 522 - OrderID:  53-430-9568 - Quantity:  1
# Result # 523 - OrderID:  53-433-8071 - Quantity:  2
# Result # 524 - OrderID:  53-494-9541 - Quantity:  2
# Result # 525 - OrderID:  53-504-3875 - Quantity:  3
# Result # 526 - OrderID:  53-541-9522 - Quantity:  2
# Result # 527 - OrderID:  53-563-4345 - Quantity:  2
# Result # 528 - OrderID:  53-585-4586 - Quantity:  3
# Result # 529 - OrderID:  53-622-3155 - Quantity:  3
# Result # 530 - OrderID:  53-661-8226 - Quantity:  2
# Result # 531 - OrderID:  53-763-8296 - Quantity:  1
# Result # 532 - OrderID:  53-851-0542 - Quantity:  1
# Result # 533 - OrderID:  53-925-0103 - Quantity:  3
# Result # 534 - OrderID:  53-974-4637 - Quantity:  2
# Result # 535 - OrderID:  54-080-0702 - Quantity:  2
# Result # 536 - OrderID:  54-162-7684 - Quantity:  3
# Result # 537 - OrderID:  54-322-1808 - Quantity:  3
# Result # 538 - OrderID:  54-366-6861 - Quantity:  2
# Result # 539 - OrderID:  54-413-3195 - Quantity:  3
# Result # 540 - OrderID:  54-501-1389 - Quantity:  3
# Result # 541 - OrderID:  54-555-7832 - Quantity:  3
# Result # 542 - OrderID:  54-800-8042 - Quantity:  2
# Result # 543 - OrderID:  54-815-3308 - Quantity:  1
# Result # 544 - OrderID:  55-209-0374 - Quantity:  2
# Result # 545 - OrderID:  55-250-4051 - Quantity:  1
# Result # 546 - OrderID:  55-263-8669 - Quantity:  3
# Result # 547 - OrderID:  55-443-2920 - Quantity:  2
# Result # 548 - OrderID:  55-592-1782 - Quantity:  2
# Result # 549 - OrderID:  55-619-8849 - Quantity:  3
# Result # 550 - OrderID:  55-676-1998 - Quantity:  3
# Result # 551 - OrderID:  55-734-7101 - Quantity:  3
# Result # 552 - OrderID:  55-932-3347 - Quantity:  1
# Result # 553 - OrderID:  56-076-6137 - Quantity:  2
# Result # 554 - OrderID:  56-184-4508 - Quantity:  3
# Result # 555 - OrderID:  56-195-4013 - Quantity:  3
# Result # 556 - OrderID:  56-271-4185 - Quantity:  3
# Result # 557 - OrderID:  56-307-1423 - Quantity:  1
# Result # 558 - OrderID:  56-331-9919 - Quantity:  3
# Result # 559 - OrderID:  56-545-1829 - Quantity:  1
# Result # 560 - OrderID:  56-644-2509 - Quantity:  2
# Result # 561 - OrderID:  56-775-4607 - Quantity:  3
# Result # 562 - OrderID:  56-840-9304 - Quantity:  2
# Result # 563 - OrderID:  56-933-2115 - Quantity:  3
# Result # 564 - OrderID:  57-393-6200 - Quantity:  1
# Result # 565 - OrderID:  57-417-7291 - Quantity:  3
# Result # 566 - OrderID:  57-683-6723 - Quantity:  2
# Result # 567 - OrderID:  57-755-0191 - Quantity:  1
# Result # 568 - OrderID:  57-761-6559 - Quantity:  1
# Result # 569 - OrderID:  57-773-2064 - Quantity:  2
# Result # 570 - OrderID:  58-064-3049 - Quantity:  3
# Result # 571 - OrderID:  58-115-0437 - Quantity:  2
# Result # 572 - OrderID:  58-149-3499 - Quantity:  3
# Result # 573 - OrderID:  58-251-6487 - Quantity:  3
# Result # 574 - OrderID:  58-287-7773 - Quantity:  3
# Result # 575 - OrderID:  58-300-9513 - Quantity:  1
# Result # 576 - OrderID:  58-326-4792 - Quantity:  3
# Result # 577 - OrderID:  58-376-5889 - Quantity:  2
# Result # 578 - OrderID:  58-419-3322 - Quantity:  3
# Result # 579 - OrderID:  58-753-8307 - Quantity:  3
# Result # 580 - OrderID:  59-023-1187 - Quantity:  3
# Result # 581 - OrderID:  59-380-4206 - Quantity:  3
# Result # 582 - OrderID:  59-493-4419 - Quantity:  2
# Result # 583 - OrderID:  59-613-6838 - Quantity:  1
# Result # 584 - OrderID:  59-617-9817 - Quantity:  2
# Result # 585 - OrderID:  59-738-2614 - Quantity:  2
# Result # 586 - OrderID:  59-784-8988 - Quantity:  2
# Result # 587 - OrderID:  59-971-2896 - Quantity:  3
# Result # 588 - OrderID:  60-009-2815 - Quantity:  3
# Result # 589 - OrderID:  60-078-2571 - Quantity:  2
# Result # 590 - OrderID:  60-081-1759 - Quantity:  1
# Result # 591 - OrderID:  60-197-5739 - Quantity:  3
# Result # 592 - OrderID:  60-230-9043 - Quantity:  1
# Result # 593 - OrderID:  60-270-8291 - Quantity:  1
# Result # 594 - OrderID:  60-600-4172 - Quantity:  3
# Result # 595 - OrderID:  60-725-6733 - Quantity:  2
# Result # 596 - OrderID:  60-885-4424 - Quantity:  1
# Result # 597 - OrderID:  60-913-9847 - Quantity:  2
# Result # 598 - OrderID:  61-057-1975 - Quantity:  3
# Result # 599 - OrderID:  61-096-3317 - Quantity:  1
# Result # 600 - OrderID:  61-097-0206 - Quantity:  3
# Result # 601 - OrderID:  61-185-3517 - Quantity:  1
# Result # 602 - OrderID:  61-501-5110 - Quantity:  3
# Result # 603 - OrderID:  61-509-9344 - Quantity:  3
# Result # 604 - OrderID:  61-533-3161 - Quantity:  3
# Result # 605 - OrderID:  61-618-8783 - Quantity:  3
# Result # 606 - OrderID:  61-622-8419 - Quantity:  3
# Result # 607 - OrderID:  61-720-5633 - Quantity:  2
# Result # 608 - OrderID:  61-721-9793 - Quantity:  2
# Result # 609 - OrderID:  61-729-8958 - Quantity:  3
# Result # 610 - OrderID:  61-753-0334 - Quantity:  1
# Result # 611 - OrderID:  61-799-5380 - Quantity:  2
# Result # 612 - OrderID:  61-841-5883 - Quantity:  3
# Result # 613 - OrderID:  62-086-4242 - Quantity:  3
# Result # 614 - OrderID:  62-201-9287 - Quantity:  3
# Result # 615 - OrderID:  62-507-3661 - Quantity:  2
# Result # 616 - OrderID:  62-591-7981 - Quantity:  2
# Result # 617 - OrderID:  62-768-3976 - Quantity:  2
# Result # 618 - OrderID:  62-918-2454 - Quantity:  2
# Result # 619 - OrderID:  63-204-3800 - Quantity:  2
# Result # 620 - OrderID:  63-236-3555 - Quantity:  1
# Result # 621 - OrderID:  63-346-9064 - Quantity:  1
# Result # 622 - OrderID:  63-453-3505 - Quantity:  1
# Result # 623 - OrderID:  63-500-9286 - Quantity:  3
# Result # 624 - OrderID:  63-555-6345 - Quantity:  3
# Result # 625 - OrderID:  63-761-3686 - Quantity:  1
# Result # 626 - OrderID:  64-051-9774 - Quantity:  2
# Result # 627 - OrderID:  64-141-5718 - Quantity:  3
# Result # 628 - OrderID:  64-427-6469 - Quantity:  2
# Result # 629 - OrderID:  64-446-6092 - Quantity:  3
# Result # 630 - OrderID:  64-569-9390 - Quantity:  3
# Result # 631 - OrderID:  64-718-6202 - Quantity:  2
# Result # 632 - OrderID:  64-918-4744 - Quantity:  3
# Result # 633 - OrderID:  64-941-6067 - Quantity:  2
# Result # 634 - OrderID:  65-080-5283 - Quantity:  1
# Result # 635 - OrderID:  65-170-4476 - Quantity:  2
# Result # 636 - OrderID:  65-249-5260 - Quantity:  3
# Result # 637 - OrderID:  65-262-1387 - Quantity:  3
# Result # 638 - OrderID:  65-301-1388 - Quantity:  2
# Result # 639 - OrderID:  65-311-3002 - Quantity:  2
# Result # 640 - OrderID:  65-329-2436 - Quantity:  3
# Result # 641 - OrderID:  65-351-6434 - Quantity:  3
# Result # 642 - OrderID:  65-386-4145 - Quantity:  2
# Result # 643 - OrderID:  65-428-6495 - Quantity:  2
# Result # 644 - OrderID:  65-432-1983 - Quantity:  3
# Result # 645 - OrderID:  65-451-1818 - Quantity:  2
# Result # 646 - OrderID:  65-485-7254 - Quantity:  3
# Result # 647 - OrderID:  65-907-3127 - Quantity:  1
# Result # 648 - OrderID:  65-919-0733 - Quantity:  3
# Result # 649 - OrderID:  65-966-4872 - Quantity:  2
# Result # 650 - OrderID:  66-056-8690 - Quantity:  3
# Result # 651 - OrderID:  66-068-8313 - Quantity:  2
# Result # 652 - OrderID:  66-188-6911 - Quantity:  3
# Result # 653 - OrderID:  66-276-1471 - Quantity:  2
# Result # 654 - OrderID:  66-392-1377 - Quantity:  2
# Result # 655 - OrderID:  66-501-9308 - Quantity:  2
# Result # 656 - OrderID:  66-525-3598 - Quantity:  3
# Result # 657 - OrderID:  66-576-7484 - Quantity:  2
# Result # 658 - OrderID:  66-610-1519 - Quantity:  2
# Result # 659 - OrderID:  66-665-1879 - Quantity:  1
# Result # 660 - OrderID:  66-679-8766 - Quantity:  3
# Result # 661 - OrderID:  66-721-3658 - Quantity:  2
# Result # 662 - OrderID:  67-009-1409 - Quantity:  3
# Result # 663 - OrderID:  67-067-9693 - Quantity:  2
# Result # 664 - OrderID:  67-156-1140 - Quantity:  2
# Result # 665 - OrderID:  67-172-7841 - Quantity:  2
# Result # 666 - OrderID:  67-382-6166 - Quantity:  3
# Result # 667 - OrderID:  67-413-6177 - Quantity:  1
# Result # 668 - OrderID:  67-455-5976 - Quantity:  1
# Result # 669 - OrderID:  67-709-5581 - Quantity:  1
# Result # 670 - OrderID:  67-723-0322 - Quantity:  2
# Result # 671 - OrderID:  67-748-7876 - Quantity:  2
# Result # 672 - OrderID:  67-799-1881 - Quantity:  3
# Result # 673 - OrderID:  67-813-5657 - Quantity:  2
# Result # 674 - OrderID:  67-816-5527 - Quantity:  3
# Result # 675 - OrderID:  67-961-1567 - Quantity:  2
# Result # 676 - OrderID:  68-012-9190 - Quantity:  2
# Result # 677 - OrderID:  68-226-7897 - Quantity:  2
# Result # 678 - OrderID:  68-323-6449 - Quantity:  1
# Result # 679 - OrderID:  68-365-1512 - Quantity:  3
# Result # 680 - OrderID:  68-391-0908 - Quantity:  3
# Result # 681 - OrderID:  68-473-3919 - Quantity:  1
# Result # 682 - OrderID:  68-844-1159 - Quantity:  1
# Result # 683 - OrderID:  69-218-2694 - Quantity:  2
# Result # 684 - OrderID:  69-254-6693 - Quantity:  3
# Result # 685 - OrderID:  69-361-9646 - Quantity:  1
# Result # 686 - OrderID:  69-562-1762 - Quantity:  3
# Result # 687 - OrderID:  69-607-3610 - Quantity:  2
# Result # 688 - OrderID:  69-624-5454 - Quantity:  3
# Result # 689 - OrderID:  69-765-1585 - Quantity:  1
# Result # 690 - OrderID:  69-780-6998 - Quantity:  3
# Result # 691 - OrderID:  69-817-5553 - Quantity:  2
# Result # 692 - OrderID:  69-817-7678 - Quantity:  3
# Result # 693 - OrderID:  70-276-7176 - Quantity:  3
# Result # 694 - OrderID:  70-349-8770 - Quantity:  2
# Result # 695 - OrderID:  70-350-8506 - Quantity:  2
# Result # 696 - OrderID:  70-365-1885 - Quantity:  3
# Result # 697 - OrderID:  70-424-5723 - Quantity:  3
# Result # 698 - OrderID:  70-821-6798 - Quantity:  2
# Result # 699 - OrderID:  71-140-6745 - Quantity:  2
# Result # 700 - OrderID:  71-188-6549 - Quantity:  2
# Result # 701 - OrderID:  71-197-3844 - Quantity:  3
# Result # 702 - OrderID:  71-274-0068 - Quantity:  1
# Result # 703 - OrderID:  71-373-6387 - Quantity:  2
# Result # 704 - OrderID:  71-409-7516 - Quantity:  2
# Result # 705 - OrderID:  71-440-8512 - Quantity:  2
# Result # 706 - OrderID:  71-485-0830 - Quantity:  3
# Result # 707 - OrderID:  71-516-9998 - Quantity:  2
# Result # 708 - OrderID:  71-828-3556 - Quantity:  3
# Result # 709 - OrderID:  71-925-2450 - Quantity:  3
# Result # 710 - OrderID:  72-015-0440 - Quantity:  1
# Result # 711 - OrderID:  72-099-2457 - Quantity:  3
# Result # 712 - OrderID:  72-207-0940 - Quantity:  2
# Result # 713 - OrderID:  72-306-1723 - Quantity:  3
# Result # 714 - OrderID:  72-325-3096 - Quantity:  2
# Result # 715 - OrderID:  72-727-1317 - Quantity:  1
# Result # 716 - OrderID:  72-823-6963 - Quantity:  3
# Result # 717 - OrderID:  73-375-8634 - Quantity:  3
# Result # 718 - OrderID:  73-455-3435 - Quantity:  3
# Result # 719 - OrderID:  73-876-5941 - Quantity:  2
# Result # 720 - OrderID:  73-900-4790 - Quantity:  1
# Result # 721 - OrderID:  73-985-2542 - Quantity:  3
# Result # 722 - OrderID:  74-006-2266 - Quantity:  2
# Result # 723 - OrderID:  74-034-2507 - Quantity:  2
# Result # 724 - OrderID:  74-302-4817 - Quantity:  3
# Result # 725 - OrderID:  74-314-5556 - Quantity:  2
# Result # 726 - OrderID:  74-339-3540 - Quantity:  3
# Result # 727 - OrderID:  74-346-3086 - Quantity:  3
# Result # 728 - OrderID:  74-564-7314 - Quantity:  2
# Result # 729 - OrderID:  74-603-8937 - Quantity:  3
# Result # 730 - OrderID:  74-776-4460 - Quantity:  2
# Result # 731 - OrderID:  74-980-5294 - Quantity:  1
# Result # 732 - OrderID:  75-362-1645 - Quantity:  1
# Result # 733 - OrderID:  75-421-5444 - Quantity:  2
# Result # 734 - OrderID:  75-463-0491 - Quantity:  3
# Result # 735 - OrderID:  75-556-0225 - Quantity:  2
# Result # 736 - OrderID:  75-606-4195 - Quantity:  2
# Result # 737 - OrderID:  75-655-7346 - Quantity:  3
# Result # 738 - OrderID:  75-714-6097 - Quantity:  3
# Result # 739 - OrderID:  75-786-1124 - Quantity:  3
# Result # 740 - OrderID:  75-883-4614 - Quantity:  3
# Result # 741 - OrderID:  76-063-7709 - Quantity:  3
# Result # 742 - OrderID:  76-176-1093 - Quantity:  1
# Result # 743 - OrderID:  76-194-5836 - Quantity:  2
# Result # 744 - OrderID:  76-201-5085 - Quantity:  3
# Result # 745 - OrderID:  76-334-1448 - Quantity:  2
# Result # 746 - OrderID:  76-380-8355 - Quantity:  2
# Result # 747 - OrderID:  76-437-5698 - Quantity:  3
# Result # 748 - OrderID:  76-509-2544 - Quantity:  2
# Result # 749 - OrderID:  76-522-9855 - Quantity:  1
# Result # 750 - OrderID:  76-627-0236 - Quantity:  2
# Result # 751 - OrderID:  76-705-8000 - Quantity:  3
# Result # 752 - OrderID:  76-746-0202 - Quantity:  3
# Result # 753 - OrderID:  76-763-0657 - Quantity:  3
# Result # 754 - OrderID:  76-769-5168 - Quantity:  1
# Result # 755 - OrderID:  76-855-7164 - Quantity:  2
# Result # 756 - OrderID:  76-867-4343 - Quantity:  2
# Result # 757 - OrderID:  76-913-8795 - Quantity:  2
# Result # 758 - OrderID:  77-083-7289 - Quantity:  1
# Result # 759 - OrderID:  77-165-4390 - Quantity:  3
# Result # 760 - OrderID:  77-180-0305 - Quantity:  1
# Result # 761 - OrderID:  77-206-4888 - Quantity:  1
# Result # 762 - OrderID:  77-325-6969 - Quantity:  1
# Result # 763 - OrderID:  77-367-2436 - Quantity:  3
# Result # 764 - OrderID:  77-527-7922 - Quantity:  1
# Result # 765 - OrderID:  77-561-4347 - Quantity:  2
# Result # 766 - OrderID:  77-635-7433 - Quantity:  1
# Result # 767 - OrderID:  77-779-8790 - Quantity:  1
# Result # 768 - OrderID:  77-827-0603 - Quantity:  3
# Result # 769 - OrderID:  77-889-7684 - Quantity:  2
# Result # 770 - OrderID:  77-904-4749 - Quantity:  2
# Result # 771 - OrderID:  77-986-1901 - Quantity:  2
# Result # 772 - OrderID:  78-040-2505 - Quantity:  2
# Result # 773 - OrderID:  78-204-9950 - Quantity:  2
# Result # 774 - OrderID:  78-214-6816 - Quantity:  3
# Result # 775 - OrderID:  78-352-3174 - Quantity:  3
# Result # 776 - OrderID:  78-407-9810 - Quantity:  3
# Result # 777 - OrderID:  78-692-7008 - Quantity:  3
# Result # 778 - OrderID:  78-803-3890 - Quantity:  1
# Result # 779 - OrderID:  78-806-0853 - Quantity:  1
# Result # 780 - OrderID:  79-268-0334 - Quantity:  2
# Result # 781 - OrderID:  79-518-4381 - Quantity:  3
# Result # 782 - OrderID:  79-555-6824 - Quantity:  2
# Result # 783 - OrderID:  79-627-2533 - Quantity:  2
# Result # 784 - OrderID:  79-638-3210 - Quantity:  3
# Result # 785 - OrderID:  79-850-0887 - Quantity:  3
# Result # 786 - OrderID:  79-946-2742 - Quantity:  3
# Result # 787 - OrderID:  80-076-4032 - Quantity:  2
# Result # 788 - OrderID:  80-215-3898 - Quantity:  2
# Result # 789 - OrderID:  80-258-5757 - Quantity:  3
# Result # 790 - OrderID:  80-349-3939 - Quantity:  3
# Result # 791 - OrderID:  80-461-9387 - Quantity:  1
# Result # 792 - OrderID:  80-489-4967 - Quantity:  1
# Result # 793 - OrderID:  80-544-0183 - Quantity:  2
# Result # 794 - OrderID:  80-616-9335 - Quantity:  1
# Result # 795 - OrderID:  80-720-7802 - Quantity:  3
# Result # 796 - OrderID:  80-727-2984 - Quantity:  1
# Result # 797 - OrderID:  80-768-1365 - Quantity:  3
# Result # 798 - OrderID:  80-784-2924 - Quantity:  3
# Result # 799 - OrderID:  80-890-3871 - Quantity:  3
# Result # 800 - OrderID:  80-923-1183 - Quantity:  1
# Result # 801 - OrderID:  80-984-7751 - Quantity:  3
# Result # 802 - OrderID:  81-109-8738 - Quantity:  1
# Result # 803 - OrderID:  81-491-8325 - Quantity:  3
# Result # 804 - OrderID:  81-493-5555 - Quantity:  2
# Result # 805 - OrderID:  81-653-6035 - Quantity:  2
# Result # 806 - OrderID:  81-819-6997 - Quantity:  1
# Result # 807 - OrderID:  81-875-5053 - Quantity:  1
# Result # 808 - OrderID:  81-881-8993 - Quantity:  3
# Result # 809 - OrderID:  81-898-7131 - Quantity:  1
# Result # 810 - OrderID:  81-940-9983 - Quantity:  2
# Result # 811 - OrderID:  82-090-4450 - Quantity:  3
# Result # 812 - OrderID:  82-287-7415 - Quantity:  1
# Result # 813 - OrderID:  82-410-4692 - Quantity:  3
# Result # 814 - OrderID:  82-422-7097 - Quantity:  3
# Result # 815 - OrderID:  82-445-5186 - Quantity:  1
# Result # 816 - OrderID:  82-505-2050 - Quantity:  3
# Result # 817 - OrderID:  82-589-4385 - Quantity:  3
# Result # 818 - OrderID:  82-639-1298 - Quantity:  2
# Result # 819 - OrderID:  82-799-6775 - Quantity:  2
# Result # 820 - OrderID:  83-217-3894 - Quantity:  3
# Result # 821 - OrderID:  83-220-9837 - Quantity:  2
# Result # 822 - OrderID:  83-262-1365 - Quantity:  3
# Result # 823 - OrderID:  83-336-8250 - Quantity:  1
# Result # 824 - OrderID:  83-499-1350 - Quantity:  3
# Result # 825 - OrderID:  83-547-0450 - Quantity:  3
# Result # 826 - OrderID:  83-584-6805 - Quantity:  1
# Result # 827 - OrderID:  83-597-0985 - Quantity:  2
# Result # 828 - OrderID:  83-687-4769 - Quantity:  3
# Result # 829 - OrderID:  83-924-4913 - Quantity:  3
# Result # 830 - OrderID:  84-007-9095 - Quantity:  3
# Result # 831 - OrderID:  84-017-7714 - Quantity:  1
# Result # 832 - OrderID:  84-039-6634 - Quantity:  2
# Result # 833 - OrderID:  84-041-9180 - Quantity:  1
# Result # 834 - OrderID:  84-561-9421 - Quantity:  1
# Result # 835 - OrderID:  84-632-0013 - Quantity:  1
# Result # 836 - OrderID:  84-681-6641 - Quantity:  2
# Result # 837 - OrderID:  84-707-3314 - Quantity:  3
# Result # 838 - OrderID:  84-724-9712 - Quantity:  2
# Result # 839 - OrderID:  84-854-1349 - Quantity:  1
# Result # 840 - OrderID:  84-864-3249 - Quantity:  1
# Result # 841 - OrderID:  84-923-5585 - Quantity:  2
# Result # 842 - OrderID:  84-951-9107 - Quantity:  1
# Result # 843 - OrderID:  84-976-0893 - Quantity:  3
# Result # 844 - OrderID:  85-196-6451 - Quantity:  2
# Result # 845 - OrderID:  85-313-3288 - Quantity:  2
# Result # 846 - OrderID:  85-463-0651 - Quantity:  1
# Result # 847 - OrderID:  85-559-9663 - Quantity:  3
# Result # 848 - OrderID:  85-569-0097 - Quantity:  2
# Result # 849 - OrderID:  85-580-7392 - Quantity:  1
# Result # 850 - OrderID:  85-795-3011 - Quantity:  1
# Result # 851 - OrderID:  85-868-5544 - Quantity:  2
# Result # 852 - OrderID:  85-912-4773 - Quantity:  1
# Result # 853 - OrderID:  85-956-0185 - Quantity:  2
# Result # 854 - OrderID:  85-961-5775 - Quantity:  2
# Result # 855 - OrderID:  86-053-9440 - Quantity:  2
# Result # 856 - OrderID:  86-114-9232 - Quantity:  2
# Result # 857 - OrderID:  86-161-8508 - Quantity:  3
# Result # 858 - OrderID:  86-227-8811 - Quantity:  3
# Result # 859 - OrderID:  86-275-9654 - Quantity:  3
# Result # 860 - OrderID:  86-400-9239 - Quantity:  1
# Result # 861 - OrderID:  86-425-5753 - Quantity:  2
# Result # 862 - OrderID:  86-581-4964 - Quantity:  1
# Result # 863 - OrderID:  86-606-8047 - Quantity:  3
# Result # 864 - OrderID:  86-668-1105 - Quantity:  3
# Result # 865 - OrderID:  86-725-2449 - Quantity:  1
# Result # 866 - OrderID:  86-819-6178 - Quantity:  2
# Result # 867 - OrderID:  87-292-9640 - Quantity:  3
# Result # 868 - OrderID:  87-409-2090 - Quantity:  3
# Result # 869 - OrderID:  87-435-5817 - Quantity:  2
# Result # 870 - OrderID:  87-443-7001 - Quantity:  1
# Result # 871 - OrderID:  87-503-4703 - Quantity:  3
# Result # 872 - OrderID:  87-530-1190 - Quantity:  2
# Result # 873 - OrderID:  87-535-8388 - Quantity:  1
# Result # 874 - OrderID:  87-546-5058 - Quantity:  3
# Result # 875 - OrderID:  87-599-0366 - Quantity:  2
# Result # 876 - OrderID:  87-618-1229 - Quantity:  2
# Result # 877 - OrderID:  87-763-3059 - Quantity:  3
# Result # 878 - OrderID:  87-766-3663 - Quantity:  3
# Result # 879 - OrderID:  87-796-6079 - Quantity:  1
# Result # 880 - OrderID:  87-820-2746 - Quantity:  1
# Result # 881 - OrderID:  87-939-7467 - Quantity:  3
# Result # 882 - OrderID:  87-976-0252 - Quantity:  2
# Result # 883 - OrderID:  87-988-3093 - Quantity:  1
# Result # 884 - OrderID:  88-109-5070 - Quantity:  3
# Result # 885 - OrderID:  88-109-8460 - Quantity:  3
# Result # 886 - OrderID:  88-367-5894 - Quantity:  3
# Result # 887 - OrderID:  88-729-8334 - Quantity:  1
# Result # 888 - OrderID:  88-756-9391 - Quantity:  2
# Result # 889 - OrderID:  88-813-0409 - Quantity:  1
# Result # 890 - OrderID:  89-007-9559 - Quantity:  1
# Result # 891 - OrderID:  89-013-4600 - Quantity:  1
# Result # 892 - OrderID:  89-100-6055 - Quantity:  2
# Result # 893 - OrderID:  89-262-2574 - Quantity:  1
# Result # 894 - OrderID:  89-266-9786 - Quantity:  1
# Result # 895 - OrderID:  89-285-0567 - Quantity:  3
# Result # 896 - OrderID:  89-306-1133 - Quantity:  3
# Result # 897 - OrderID:  89-464-8624 - Quantity:  3
# Result # 898 - OrderID:  89-513-4206 - Quantity:  3
# Result # 899 - OrderID:  89-535-2329 - Quantity:  3
# Result # 900 - OrderID:  89-865-3770 - Quantity:  2
# Result # 901 - OrderID:  89-997-5952 - Quantity:  3
# Result # 902 - OrderID:  90-006-4375 - Quantity:  1
# Result # 903 - OrderID:  90-122-2737 - Quantity:  3
# Result # 904 - OrderID:  90-256-2320 - Quantity:  2
# Result # 905 - OrderID:  90-317-7928 - Quantity:  3
# Result # 906 - OrderID:  90-320-2065 - Quantity:  2
# Result # 907 - OrderID:  90-359-2449 - Quantity:  3
# Result # 908 - OrderID:  90-389-3298 - Quantity:  2
# Result # 909 - OrderID:  90-478-9446 - Quantity:  3
# Result # 910 - OrderID:  90-716-3855 - Quantity:  2
# Result # 911 - OrderID:  90-877-0957 - Quantity:  2
# Result # 912 - OrderID:  90-878-2657 - Quantity:  3
# Result # 913 - OrderID:  90-921-1904 - Quantity:  2
# Result # 914 - OrderID:  90-989-2851 - Quantity:  3
# Result # 915 - OrderID:  91-006-3876 - Quantity:  3
# Result # 916 - OrderID:  91-121-2326 - Quantity:  2
# Result # 917 - OrderID:  91-163-7915 - Quantity:  3
# Result # 918 - OrderID:  91-242-5776 - Quantity:  2
# Result # 919 - OrderID:  91-284-4644 - Quantity:  2
# Result # 920 - OrderID:  91-332-6187 - Quantity:  2
# Result # 921 - OrderID:  91-490-5244 - Quantity:  2
# Result # 922 - OrderID:  91-659-9644 - Quantity:  1
# Result # 923 - OrderID:  91-690-3480 - Quantity:  3
# Result # 924 - OrderID:  91-855-3626 - Quantity:  2
# Result # 925 - OrderID:  92-282-7155 - Quantity:  3
# Result # 926 - OrderID:  92-392-7061 - Quantity:  2
# Result # 927 - OrderID:  92-487-3562 - Quantity:  1
# Result # 928 - OrderID:  92-521-6256 - Quantity:  2
# Result # 929 - OrderID:  92-555-9940 - Quantity:  2
# Result # 930 - OrderID:  92-610-5614 - Quantity:  3
# Result # 931 - OrderID:  92-660-8297 - Quantity:  2
# Result # 932 - OrderID:  92-747-8084 - Quantity:  2
# Result # 933 - OrderID:  92-776-2834 - Quantity:  2
# Result # 934 - OrderID:  92-795-7087 - Quantity:  3
# Result # 935 - OrderID:  92-809-9028 - Quantity:  2
# Result # 936 - OrderID:  92-833-3271 - Quantity:  3
# Result # 937 - OrderID:  92-838-7961 - Quantity:  2
# Result # 938 - OrderID:  92-859-5564 - Quantity:  2
# Result # 939 - OrderID:  92-873-3440 - Quantity:  2
# Result # 940 - OrderID:  92-880-1942 - Quantity:  1
# Result # 941 - OrderID:  93-057-9662 - Quantity:  2
# Result # 942 - OrderID:  93-083-3241 - Quantity:  2
# Result # 943 - OrderID:  93-396-2857 - Quantity:  2
# Result # 944 - OrderID:  93-409-8648 - Quantity:  3
# Result # 945 - OrderID:  93-702-4764 - Quantity:  1
# Result # 946 - OrderID:  93-829-0535 - Quantity:  2
# Result # 947 - OrderID:  93-829-3135 - Quantity:  1
# Result # 948 - OrderID:  93-892-9924 - Quantity:  2
# Result # 949 - OrderID:  94-106-4253 - Quantity:  2
# Result # 950 - OrderID:  94-148-7497 - Quantity:  1
# Result # 951 - OrderID:  94-211-8782 - Quantity:  2
# Result # 952 - OrderID:  94-670-7121 - Quantity:  1
# Result # 953 - OrderID:  95-007-7718 - Quantity:  2
# Result # 954 - OrderID:  95-025-5981 - Quantity:  1
# Result # 955 - OrderID:  95-337-7409 - Quantity:  2
# Result # 956 - OrderID:  95-524-7993 - Quantity:  1
# Result # 957 - OrderID:  95-551-4400 - Quantity:  2
# Result # 958 - OrderID:  95-581-1944 - Quantity:  2
# Result # 959 - OrderID:  95-581-6863 - Quantity:  1
# Result # 960 - OrderID:  95-587-8796 - Quantity:  2
# Result # 961 - OrderID:  95-599-9120 - Quantity:  1
# Result # 962 - OrderID:  95-666-2867 - Quantity:  3
# Result # 963 - OrderID:  95-846-1036 - Quantity:  1
# Result # 964 - OrderID:  95-935-6126 - Quantity:  3
# Result # 965 - OrderID:  96-049-6957 - Quantity:  3
# Result # 966 - OrderID:  96-173-6690 - Quantity:  3
# Result # 967 - OrderID:  96-257-8035 - Quantity:  1
# Result # 968 - OrderID:  96-458-9557 - Quantity:  3
# Result # 969 - OrderID:  96-491-1316 - Quantity:  2
# Result # 970 - OrderID:  96-813-6384 - Quantity:  1
# Result # 971 - OrderID:  96-883-6756 - Quantity:  2
# Result # 972 - OrderID:  96-993-3962 - Quantity:  1
# Result # 973 - OrderID:  97-004-1775 - Quantity:  3
# Result # 974 - OrderID:  97-039-9333 - Quantity:  1
# Result # 975 - OrderID:  97-219-4069 - Quantity:  3
# Result # 976 - OrderID:  97-233-2887 - Quantity:  1
# Result # 977 - OrderID:  97-246-5273 - Quantity:  1
# Result # 978 - OrderID:  97-507-9861 - Quantity:  2
# Result # 979 - OrderID:  97-554-4987 - Quantity:  2
# Result # 980 - OrderID:  97-623-6572 - Quantity:  3
# Result # 981 - OrderID:  97-662-2177 - Quantity:  2
# Result # 982 - OrderID:  97-710-0241 - Quantity:  1
# Result # 983 - OrderID:  97-905-7691 - Quantity:  2
# Result # 984 - OrderID:  97-946-2509 - Quantity:  1
# Result # 985 - OrderID:  97-995-3154 - Quantity:  1
# Result # 986 - OrderID:  98-115-7191 - Quantity:  3
# Result # 987 - OrderID:  98-148-9592 - Quantity:  3
# Result # 988 - OrderID:  98-293-6058 - Quantity:  2
# Result # 989 - OrderID:  98-391-7796 - Quantity:  1
# Result # 990 - OrderID:  98-646-1456 - Quantity:  3
# Result # 991 - OrderID:  98-889-5403 - Quantity:  3
# Result # 992 - OrderID:  98-920-8331 - Quantity:  2
# Result # 993 - OrderID:  99-207-8914 - Quantity:  1
# Result # 994 - OrderID:  99-346-2194 - Quantity:  1
# Result # 995 - OrderID:  99-664-1580 - Quantity:  2
# Result # 996 - OrderID:  99-679-0062 - Quantity:  1
# Result # 997 - OrderID:  99-748-0471 - Quantity:  2
# Result # 998 - OrderID:  99-860-3106 - Quantity:  2
# Result # 999 - OrderID:  99-862-6759 - Quantity:  3
# Result # 1000 - OrderID:  99-900-7458 - Quantity:  2

# %% [markdown]
# # Task 4: Create a stored procedure that manages booking.

# %%
# Create a Virtual Table (View) that returns all rows from all tables 
DropDataFromAllTables_sql = """DROP VIEW IF EXISTS DataFromAllTables;"""
DataFromAllTables_sql = """CREATE VIEW DataFromAllTables AS
SELECT da.AddressID, da.City, da.Country, da.PostalCode, da.CountryCode,
p.ProductID, p.CourseName, p.CuisineName, p.StarterName, p.DesertName, p.DrinkName, p.SidesName,
c.CustomerID, c.FirstName, c.LastName,
o.OrderID, o.OrderDate,
od.OrderdetailsID, od.DeliveryDate, od.DeliveryCost, od.Quantity, od.CostPrice, od.Salesprice,
od.Discount
FROM DeliveryAddress da, Products p, Customers c, Orders o, OrderDetails od 
WHERE c.CustomerID = o.CustomerID AND da.AddressID=od.AddressID AND
o.OrderID=od.OrderID AND p.ProductID=od.ProductID;"""

#Create the View
try:
    cursor.execute(DropDataFromAllTables_sql) 
    cursor.execute(DataFromAllTables_sql) 
    print("View successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# View successfully created or already exists.

# %%
#Stored Procedure ManageBooking() that selects data about the last 5 bookings
DropManageBooking_sql ="""DROP PROCEDURE IF EXISTS ManageBooking;"""
ManageBooking_sql = """CREATE PROCEDURE IF NOT EXISTS ManageBooking()
    BEGIN 
        SELECT DISTINCT (OrderID), CustomerID, OrderDate, AddressID, DeliveryDate  
        FROM `DataFromAllTables` 
        ORDER BY OrderDate DESC
        LIMIT 5;
    END;"""

#Create the Stored Procedure
try:
    cursor.execute(DropManageBooking_sql) 
    cursor.execute(ManageBooking_sql) 
    print("Procedure successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Procedure successfully created or already exists.

# %%
#Retrieve data from the Stored Procedure
try:
    cursor.callproc('ManageBooking')
    allResults=[]
    for eachResult in cursor.stored_results():
        ds = eachResult.fetchall()
        i=1
        for eachResult in ds:
            print('Result #', i, "- OrderID: ",eachResult[0],"- CustomerID: ",eachResult[1],
                                 "- OrderDate: ",eachResult[2],"- AddressID: ",eachResult[3],"- DeliveryDate: ",eachResult[4])
            i=i+1
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Result # 1 - OrderID:  57-000-2024 - CustomerID:  99-788-9999 - OrderDate:  2024-04-02 - AddressID:  MONTREAL-CAN-H1N4G6-1 - DeliveryDate:  2024-04-15
# Result # 2 - OrderID:  52-708-9153 - CustomerID:  91-757-8892 - OrderDate:  2023-01-06 - AddressID:  KANSASCITY-UNI-6496418-1 - DeliveryDate:  2022-11-18
# Result # 3 - OrderID:  52-708-9153 - CustomerID:  91-757-8892 - OrderDate:  2023-01-06 - AddressID:  KANSASCITY-UNI-353748-1 - DeliveryDate:  2022-11-18
# Result # 4 - OrderID:  52-708-9153 - CustomerID:  91-757-8892 - OrderDate:  2023-01-06 - AddressID:  KANSASCITY-UNI-9930300-1 - DeliveryDate:  2022-11-18
# Result # 5 - OrderID:  52-708-9153 - CustomerID:  91-757-8892 - OrderDate:  2023-01-06 - AddressID:  KANSASCITY-UNI-9870562-1 - DeliveryDate:  2022-11-18

# %% [markdown]
# # Task 5: Create a stored procedure that adds bookings.

# %%
#Stored Procedure AddBooking() that inserts a booking into the database. 
DropAddBooking_sql ="""DROP PROCEDURE IF EXISTS AddBooking;"""
AddBooking_sql ="""CREATE PROCEDURE IF NOT EXISTS AddBooking( 
                    IN addressid VARCHAR(45), 
                    IN city VARCHAR(45),
                    IN country VARCHAR(45),
                    IN postalcode VARCHAR(45),
                    IN countrycode VARCHAR(45),

                    IN productid VARCHAR(45),
                    
                    IN customerid VARCHAR(45),
                    IN firstname VARCHAR(45),
                    IN lastname VARCHAR(45),

                    IN orderid VARCHAR(45),
                    
                    IN deliverydate DATE,
                    IN deliverycost DECIMAL,
                    IN quantity INT,
                    IN costprice DECIMAL,
                    IN discount DECIMAL)
    BEGIN
        DECLARE coursename VARCHAR(45) DEFAULT 'NULL';
        DECLARE cuisinename VARCHAR(45) DEFAULT 'NULL';
        DECLARE startername VARCHAR(45) DEFAULT 'NULL';
        DECLARE desertname VARCHAR(45) DEFAULT 'NULL';
        DECLARE drinkname VARCHAR(45) DEFAULT 'NULL';
        DECLARE sidesname VARCHAR(45) DEFAULT 'NULL';

        SELECT Products.CourseName FROM Products WHERE Products.ProductID=productid INTO coursename;
        SELECT Products.CuisineName FROM Products WHERE Products.ProductID=productid INTO cuisinename;
        SELECT Products.StarterName FROM Products WHERE Products.ProductID=productid INTO startername;
        SELECT Products.DesertName FROM Products WHERE Products.ProductID=productid INTO desertname;
        SELECT Products.DrinkName FROM Products WHERE Products.ProductID=productid INTO drinkname;
        SELECT Products.SidesName FROM Products WHERE Products.ProductID=productid INTO sidesname;
        
        IF (coursename IS NOT NULL AND cuisinename IS NOT NULL AND startername IS NOT NULL
            AND desertname IS NOT NULL AND drinkname IS NOT NULL AND sidesname IS NOT NULL)
            THEN 
                INSERT INTO DeliveryAddress
                    VALUES (addressid, city, country, postalcode, countrycode);

                INSERT INTO Customers 
                    VALUES (customerid, firstname, lastname);

                INSERT INTO Orders 
                    VALUES (orderid, now(), customerid);

                INSERT INTO OrderDetails(DeliveryDate, DeliveryCost, Quantity, CostPrice, Discount, AddressID, OrderID, ProductID) 
                    VALUES (deliverydate, deliverycost, quantity, costprice, discount, addressid, orderid, productid); 
        END IF;
    END;"""

#Create the Stored Procedure
try:
    cursor.execute(DropAddBooking_sql) 
    cursor.execute(AddBooking_sql) 
    print("Procedure successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Procedure successfully created or already exists.

# %%
#Insert records via the Stored Procedure
args=['MONTREAL-CAN-H1N4G6-1','Montreal','Canada','H1N4G6','CA','CarItaFalAffRomFoc1','99-788-9999','Jane','Doe','57-000-2024','2024-04-15', 11.50, 6, 230.50, 33.00] 

try:
    cursor.callproc('AddBooking', args)
    cnx.commit()
    print("A new booking was successfully added in the database")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# A new booking was successfully added in the database

# %%
#Check that the booking added previously is successfully recorded
#Select all records from the View
select_view_DataFromAllTables_sql = """SELECT * FROM  DataFromAllTables
                                WHERE OrderId='57-000-2024';"""

#Execute queries
try:
    cursor.execute(select_view_DataFromAllTables_sql) 
    result=cursor.fetchall()
    print('\n'.join([', '.join(map(str,t)) for t in result]))
    print()
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# MONTREAL-CAN-H1N4G6-1, Montreal, Canada, H1N4G6, CA, CarItaFalAffRomFoc1, Carbonara, Italian, Falafel, Affogato, Roma Red wine, Focaccia, 99-788-9999, Jane, Doe, 57-000-2024, 2024-04-02, 21001, 2024-04-15, 12.00, 6, 231.00, 346.50, 33.00

# %% [markdown]
# # Task 6: Create a stored procedure that updates bookings.

# %%
#Stored Procedure AddBooking() that updates a booking into the database 
DropUpdateBooking_sql ="""DROP PROCEDURE IF EXISTS UpdateBooking;"""
UpdateBooking_sql ="""CREATE PROCEDURE IF NOT EXISTS UpdateBooking( 
                    IN orderdetailsid INT,
                    IN deliverydate DATE,
                    IN deliverycost DECIMAL,
                    IN quantity INT,
                    IN costprice DECIMAL,
                    IN discount DECIMAL,
                    IN productid VARCHAR(45))
    BEGIN
        UPDATE OrderDetails SET 
        OrderDetails.DeliveryDate=deliverydate,
        OrderDetails.DeliveryCost=deliverycost,
        OrderDetails.Quantity=quantity,
        OrderDetails.Costprice=costprice,
        OrderDetails.Discount=discount,
        OrderDetails.ProductID=productid 
        WHERE OrderDetails.OrderDetailsID = orderdetailsid;
    END;"""

#Create the Stored Procedure
try:
    cursor.execute(DropUpdateBooking_sql) 
    cursor.execute(UpdateBooking_sql) 
    print("Procedure successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Procedure successfully created or already exists.

# %%
#Check the booking to be modified before modification
#Select all records from the View
select_view_DataFromAllTables_sql = """SELECT * FROM  DataFromAllTables
                                WHERE OrderDetailsId='21001';"""

#Execute queries
try:
    cursor.execute(select_view_DataFromAllTables_sql) 
    result=cursor.fetchall()
    print('\n'.join([', '.join(map(str,t)) for t in result]))
    print()
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# MONTREAL-CAN-H1N4G6-1, Montreal, Canada, H1N4G6, CA, CarItaFalAffRomFoc1, Carbonara, Italian, Falafel, Affogato, Roma Red wine, Focaccia, 99-788-9999, Jane, Doe, 57-000-2024, 2024-04-02, 21001, 2024-04-15, 12.00, 6, 231.00, 346.50, 33.00

# %%
#Modify records via the Stored Procedure
args=[21001,'2024-05-30', 200, 19, 401.00, 12,'BeaTurTomIceCorPot1'] 

try:
    cursor.callproc('UpdateBooking', args)
    cnx.commit()
    print("The booking was successfully updated in the database")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# The booking was successfully updated in the database

# %%
#Check the booking modified after modification
#Select all records from the View
select_view_DataFromAllTables_sql = """SELECT * FROM  DataFromAllTables
                                WHERE OrderDetailsId='21001';"""

#Execute queries
try:
    cursor.execute(select_view_DataFromAllTables_sql) 
    result=cursor.fetchall()
    print('\n'.join([', '.join(map(str,t)) for t in result]))
    print()
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# MONTREAL-CAN-H1N4G6-1, Montreal, Canada, H1N4G6, CA, BeaTurTomIceCorPot1, Bean soup, Turkish, Tomato bread, Ice cream, Corfu Red Wine, Potato salad, 99-788-9999, Jane, Doe, 57-000-2024, 2024-04-02, 21001, 2024-05-30, 200.00, 19, 401.00, 601.50, 12.00

# %% [markdown]
# # Task 7: Create a stored procedure that cancels bookings.

# %%
#Stored Procedure AddBooking() that deletes a booking into the database 
DropCancelBooking_sql ="""DROP PROCEDURE IF EXISTS CancelBooking;"""
CancelBooking_sql ="""CREATE PROCEDURE IF NOT EXISTS CancelBooking( 
                    IN orderid VARCHAR(45))
    BEGIN
        DELETE FROM Orders 
        WHERE `Orders`.`OrderID` = orderid;
    END;"""

#Create the Stored Procedure
try:
    cursor.execute(DropCancelBooking_sql) 
    cursor.execute(CancelBooking_sql) 
    print("Procedure successfully created or already exists.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# Procedure successfully created or already exists.

# %%
#Check the booking to be cancelled before delation
#Select all records from the View
select_view_DataFromAllTables_sql = """SELECT * FROM  DataFromAllTables
                                WHERE OrderId='00-008-3271';"""

#Execute queries
try:
    cursor.execute(select_view_DataFromAllTables_sql) 
    result=cursor.fetchall()
    print('\n'.join([', '.join(map(str,t)) for t in result]))
    print()
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# ZŁOTNIKI-POL-6496345-1, Złotniki, Poland, 649-6345, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 333, 2022-12-29, 22.25, 2, 310.00, 465.00, 67.77
# ZŁOTNIKI-POL-86030300-1, Złotniki, Poland, 86030300, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 1333, 2022-12-29, 22.25, 2, 91.84, 137.76, 94.76
# ZŁOTNIKI-POL-9870489-1, Złotniki, Poland, 987-0489, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 2333, 2022-12-29, 22.25, 2, 320.00, 480.00, 91.41
# ZŁOTNIKI-POL-9930227-1, Złotniki, Poland, 993-0227, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 3333, 2022-12-29, 22.25, 2, 93.13, 139.70, 24.00
# ZŁOTNIKI-POL-121364080.7-1, Złotniki, Poland, -121364080.7, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 4333, 2022-12-29, 22.25, 2, 75.00, 112.50, 35.44
# ZŁOTNIKI-POL-6496639-1, Złotniki, Poland, 649-6639, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 5333, 2022-12-29, 22.25, 2, 144.09, 216.14, 20.00
# ZŁOTNIKI-POL-693141-1, Złotniki, Poland, 693141, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 6333, 2022-12-29, 22.25, 2, 125.00, 187.50, 9.71
# ZŁOTNIKI-POL-471922625-1, Złotniki, Poland, 471922625, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 7333, 2022-12-29, 22.25, 2, 168.27, 252.41, 10.00
# ZŁOTNIKI-POL-438687966-1, Złotniki, Poland, 438687966, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 8333, 2022-12-29, 22.25, 2, 69.38, 104.07, 31.20
# ZŁOTNIKI-POL-262846512.7-1, Złotniki, Poland, -262846512.7, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 9333, 2022-12-29, 22.25, 2, 190.00, 285.00, 15.00
# ZŁOTNIKI-POL-958 01-1, Złotniki, Poland, 958 01, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 10333, 2022-12-29, 22.25, 2, 52.08, 78.12, 80.34
# ZŁOTNIKI-POL-34285-1, Złotniki, Poland, 34285, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 11333, 2022-12-29, 22.25, 2, 310.00, 465.00, 53.53
# ZŁOTNIKI-POL-38101485-1, Złotniki, Poland, 3810-1485, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 12333, 2022-12-29, 22.25, 2, 91.84, 137.76, 61.49
# ZŁOTNIKI-POL-1135 01-1, Złotniki, Poland, 1135 01, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 13333, 2022-12-29, 22.25, 2, 320.00, 480.00, 10.52
# ZŁOTNIKI-POL-753797586-1, Złotniki, Poland, 753797586, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 14333, 2022-12-29, 22.25, 2, 93.13, 139.70, 54.08
# ZŁOTNIKI-POL-432177296.7-1, Złotniki, Poland, -432177296.7, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 15333, 2022-12-29, 22.25, 2, 75.00, 112.50, 23.00
# ZŁOTNIKI-POL-354675-1, Złotniki, Poland, 354675, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 16333, 2022-12-29, 22.25, 2, 144.09, 216.14, 91.14
# ZŁOTNIKI-POL-6497345-1, Złotniki, Poland, 649-7345, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 17333, 2022-12-29, 22.25, 2, 125.00, 187.50, 11.23
# ZŁOTNIKI-POL-1180760300-1, Złotniki, Poland, 1180760300, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 18333, 2022-12-29, 22.25, 2, 168.27, 252.41, 98.01
# ZŁOTNIKI-POL-9871489-1, Złotniki, Poland, 987-1489, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 19333, 2022-12-29, 22.25, 2, 69.38, 104.07, 73.09
# ZŁOTNIKI-POL-9931227-1, Złotniki, Poland, 993-1227, PL, PizGreTomCheItaBru1, Pizza, Greek, Tomato bread, Cheesecake, Italian Coffee, Bruschetta, 50-245-9029, Pansie, Alldis, 00-008-3271, 2021-05-24, 20333, 2022-12-29, 22.25, 2, 190.00, 285.00, 97.48

# %%
#Delete records via the Stored Procedure
args=['00-008-3271'] 

try:
    cursor.callproc('CancelBooking', args)
    cnx.commit()
    print("The booking was successfully cancelled in the database")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# The booking was successfully cancelled in the database

# %%
#Check the booking cancelled after delation
#Select all records from the View
select_view_DataFromAllTables_sql = """SELECT * FROM  DataFromAllTables
                                WHERE OrderId='00-008-3271';"""

#Execute queries
try:
    cursor.execute(select_view_DataFromAllTables_sql) 
    result=cursor.fetchall()
    if(result):
        print('\n'.join([', '.join(map(str,t)) for t in result]))
        print()
    else:
        print("An empty result set id returned. This order doesn't exist.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
# Out:
# An empty result set id returned. This order doesn't exist.

# %% [markdown]
# # Optional Task - Drop the Tables, View and Procedures.

# %%
#SQL code to drop the Procedures
dropAllDBItems=[
    """DROP PROCEDURE IF EXISTS GetMaxQuantity;""", 
    """DROP PROCEDURE IF EXISTS GetAllMaxQuantity;""", 
    """DROP PROCEDURE IF EXISTS ManageBooking;""",
    """DROP PROCEDURE IF EXISTS AddBooking;""",
    """DROP PROCEDURE IF EXISTS UpdateBooking;""",
    """DROP PROCEDURE IF EXISTS CancelBooking;"""
]

"""
#Drop the Procedures
try:
    for dropEachDBitem in dropAllDBItems:
        cursor.execute(dropEachDBitem) 
        print(dropEachDBitem,"was executed successfully.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
"""
# Out:
# '\n#Drop the Procedures\ntry:\n    for dropEachDBitem in dropAllDBItems:\n        cursor.execute(dropEachDBitem) \n        print(dropEachDBitem,"was executed successfully.")\nexcept Error as er:\n    print("Something went wrong.")\n    print("Error Code:", er.errno)\n    print("Error Message:", er.msg)\n'

# %%
#SQL code to drop the View and Tables
dropAllDBItems=[
    """DROP VIEW DataFromAllTables;""",
    """DROP TABLE OrderDetails;""", 
    """DROP TABLE Orders;""",
    """DROP TABLE Customers;""",
    """DROP TABLE DeliveryAddress;""",
    """DROP TABLE Products;"""
]
"""
#Drop the View and Tables
try:
    for dropEachDBitem in dropAllDBItems:
        cursor.execute(dropEachDBitem) 
        print(dropEachDBitem,"was executed successfully.")
except Error as er:
    print("Something went wrong.")
    print("Error Code:", er.errno)
    print("Error Message:", er.msg)
"""
# Out:
# '\n#Drop the View and Tables\ntry:\n    for dropEachDBitem in dropAllDBItems:\n        cursor.execute(dropEachDBitem) \n        print(dropEachDBitem,"was executed successfully.")\nexcept Error as er:\n    print("Something went wrong.")\n    print("Error Code:", er.errno)\n    print("Error Message:", er.msg)\n'

# %% [markdown]
# # Final Task - Close the cursor and connection.

# %%
#Disconnect the cursor
cursor.close()
print("The cursor was successfully closed.")
# Out:
# The cursor was successfully closed.

# %%
#Disconnect from MySQL
cnx.close()
print ("Successfully disconnected from MySQL.")
# Out:
# Successfully disconnected from MySQL.
